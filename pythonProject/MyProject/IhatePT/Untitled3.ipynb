# %% [markdown]
# # Data setting

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers
# tf.__version__
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
student = pd.read_csv('./student_sentence_data.csv')
teacher = pd.read_csv('./teacher_sentence_data.csv')

# %%
student
# Out:
#                            sentence_id  \
# 0     20df21b159a5e1d0ee484c936f1597ef
# 1     1b90bfe67b06a515eec82e88e1bd7d84
# 2     2673ce8234cc65bf5d5e81743172700b
# 3     98fdeabb8c02fc9ed1ce18a72fb7e84b
# 4     60cd307ed0ad93d58635cb0d9d58e1e6
# ...                                ...
# 1729  a2cb57d228407136bd5bd7d1258af2fe
# 1730  51dc29f0fc5109927bdee5fa23afb09f
# 1731  9cd6dbaf1d9d205d0cb5d9f2263a710c
# 1732  4fb845c67d91bcb3178498fc6fe1fedc
# 1733  23c1da8bea3118d0e9f2baf61fdf3973
#
#                                                sentence  \
# 0     Suppose you need to measure the temperature in...
# 1               There are different kinds of knowledge.
# 2                                                  Why?
# 3     You can be perfect, but you need to change the...
# 4     He was a violinist and composer known for his ...
# ...                                                 ...
# 1729  Or, from the perspective of the character, Who...
# 1730                                Who is this person?
# 1731  If there's a single secret to storytelling the...
# 1732                                              Diego
# 1733  Animals can become famous for many different r...
#
#                                         answer  label
# 0              너는 농작물 밭에서 온도를 측정할 필요가 있다고 가정해라      1
# 1                               지식에는 다른 종류가 있다      1
# 2                                          왜일까      1
# 3        너는 완벽할 수 있지만, 그것을 생각하는 방식을 변화할 필요가 있다      1
# 4     그는 유니크한 퍼포먼스 방법으로 알려져있는 바이올리니스트이자 작곡가였다.      1
# ...                                        ...    ...
# 1729                       또는 등장인물의 관점애서 난 ㄴㄱ?      1
# 1730                                     얘 ㄴㄱ?      1
# 1731        만약 이야기하기에 한가지ㅜ비밀이 있다면 난 그게ㅜ이거라 믿는다      1
# 1732                                       디에고      1
# 1733                      동물들은많은다양한이유들로유명해질수있다      1
#
# [1734 rows x 4 columns]

# %%
import warnings
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer

warnings.filterwarnings('ignore')

# %%
student['answer'] = student['answer'].str.replace('[^0-9가-힣]',' ')
teacher['answer'] = teacher['answer'].str.replace('[^0-9가-힣]',' ')

# %% [markdown]
# # Soynlp tokenizer

# %%
import soynlp
from soynlp.noun import LRNounExtractor_v2
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor
from soynlp.tokenizer import LTokenizer

import warnings
warnings.filterwarnings('ignore')

# %%
import collections

def corpus_init():
    f = open("./corpus_target.txt", 'w',encoding='utf8')
    f.write('')
    f.close()

def corpus_save(target):
    save = '\n'.join(target)
    f = open("./corpus_target.txt", 'a',encoding='utf8')
    f.write(save)
    f.close()
    
    
def stop_save(target):
    save = '\n'.join(target)
    f = open("./stopwords.txt", 'a',encoding='utf8')
    f.write(save)
    f.close()
    
def return_tokenizer():
    corpus = DoublespaceLineCorpus("./corpus_target.txt",iter_sent=True)
    noun_extractor = LRNounExtractor_v2(verbose=True) # n_gram?
    nouns = noun_extractor.train_extract(corpus)
    scores = {word:score.score for word, score in nouns.items()}
    tokenizer = LTokenizer(scores=scores)
    return tokenizer

# %%
target = list(teacher['answer'].str.replace('[^0-9가-힣]',' '))
target.extend(list(student['answer'].str.replace('[^0-9가-힣]',' ')))

# %%
corpus_init()
corpus_save(target)

# %%
tokenizer = return_tokenizer()
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 13631 from 5338 sents. mem=0.315 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=35740, mem=0.339 Gb
# [Noun Extractor] batch prediction was completed for 5368 words
# [Noun Extractor] checked compounds. discovered 321 compounds
# [Noun Extractor] postprocessing detaching_features : 2365 -> 2311
# [Noun Extractor] postprocessing ignore_features : 2311 -> 2272
# [Noun Extractor] postprocessing ignore_NJ : 2272 -> 2256
# [Noun Extractor] 2256 nouns (321 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.345 Gb
# [Noun Extractor] 62.14 % eojeols are covered

# %%
tokenizer(student['answer'][0])
# Out:
# ['너는', '농작물', '밭에서', '온도', '를', '측정', '할', '필요가', '있다고', '가정', '해라']

# %%
clean_train_answer = [tokenizer(i) for i in student['answer']]
clean_train_answer.extend([tokenizer(i) for i in teacher['answer']])

# %%
stop_words = set(['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한','를','을','에'])
def cleaner(target_sentence):
    target_sentence = collections.deque(target_sentence)
    for _ in range(len(target_sentence)):
        tar = target_sentence.popleft()
        if tar not in stop_words:
             target_sentence.append(tar)
    return list(target_sentence)

# %%
tp = []
for i in clean_train_answer:
    tp.extend(i)

import collections
only_word = []
tp = collections.Counter(tp)
for i in tp.keys():
    if tp[i] == 1:
        only_word.append(i)

# %%
ct_word = pd.DataFrame()
ct_word['word'] = tp.keys()
ct_word['count'] = tp.values()
ct_word.sort_values(by='count',ascending=False,inplace=True)

ct_word.head(10)
# Out:
#     word  count
# 46     의   1338
# 22     을   1223
# 63     은   1120
# 112    이    992
# 48     에    883
# 4      를    764
# 57     는    664
# 15     가    507
# 125    한    494
# 24    하는    398

# %%
stop = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한','를','을','에','적','할','인가가',
        '해서','된','도','인','로','함']
# stop.extend(only_word)
stop_words = set(stop)
stop_save(stop_words)

# %%
test = tokenizer(student['answer'][0])
cleaner(test)
# Out:
# ['너는', '농작물', '밭에서', '온도', '측정', '필요가', '있다고', '가정', '해라']

# %%
clean_train_answer = [cleaner(tokenizer(i)) for i in student['answer']]
clean_train_answer
# Out:
# [['너는', '농작물', '밭에서', '온도', '측정', '필요가', '있다고', '가정', '해라'],
#  ['지식', '에는', '다른', '종류', '있다'],
#  ['왜일까'],
#  ['너는', '완벽', '있지만', '그것', '생각', '하는', '방식', '변화', '필요가', '있다'],
#  ['그는', '유니크한', '퍼포먼스', '방법', '으로', '알려져', '있는', '바이올리니스트이자', '작곡', '가였다'],
#  ['누가', '그들', '비난', '할수있나'],
#  ['고생', '물학자들은', '지구', '에서', '생명', '역사', '집중', '한다'],
#  ['랍스터', '치킨', '만큼', '저렴', '하면', '우리', '그것', '덜', '즐길', '지도', '모른다'],
#  ['복원', '청소하고', '피해', '입은', '서식지', '다시', '만드는', '걸', '포함', '한다'],
#  ['우리',
#   '부엌',
#   '으로',
#   '향하는',
#   '옆문으로',
#   '들어왔을때',
#   '나는',
#   '무엇',
#   '잘못',
#   '되었다는것을',
#   '즉시',
#   '알았다'],
#  ['여기', '아름', '다운', '무지', '개', '보세요'],
#  ['나는', '무언가가', '벽을', '따라서', '느리게', '움직', '이는것을', '들었다'],
#  ['하나의', '문화', '다른', '문화', '보다', '나은지를', '어떻게', '결정', '할지', '알기', '어렵다'],
#  ['1824년', '페루', '스페인으로부터', '자유', '얻었다'],
#  ['문화', '또한', '역할', '한다'],
#  ['그것', '더', '쉽고', '편하다'],
#  ['사람들', '영웅', '사랑', '한다'],
#  ['그는', '주위', '세상', '모든', '방향', '으로', '움직', '이는', '이상', '기분', '느꼈다'],
#  ['그것', '완벽', '하다'],
#  ['그의', '아버지', '그가', '교회', '목사가', '되기를', '바랐지만', '그는', '음악', '직업', '갈망', '했다'],
#  ['그는',
#   '70개',
#   '이상',
#   '작품',
#   '했던거로',
#   '여겨지지만',
#   '오늘날',
#   '10개정도',
#   '작품',
#   '만이',
#   '남아',
#   '있다'],
#  ['감히', '몇몇', '상어', '와', '바다', '독수리들만이', '바다뱀', '들을', '공격', '한다'],
#  ['차', '알약', '대신', '복용해라'],
#  ['너가', '가장', '많이', '쇼핑', '하는', '식료품점', '상상', '해라'],
#  ['바닷가재', '치킨', '만큼', '싸지면', '우리', '그것', '덜', '즐길지도', '모른다'],
#  ['보안',
#   '또다른',
#   '걱정',
#   '쿠키',
#   '공유',
#   '컴퓨터',
#   '들을',
#   '훨씬',
#   '덜',
#   '안전',
#   '하게',
#   '만들고',
#   '해커',
#   '에게',
#   '시스템',
#   '침입',
#   '하는',
#   '방법',
#   '들을',
#   '제공',
#   '한다'],
#  ['게으르고', '태평', '스러운'],
#  ['강한', '글은', '구체적', '이다'],
#  ['2013년',
#   '베이징',
#   '에서',
#   '위험',
#   '하게',
#   '높은',
#   '오염',
#   '수준',
#   '으로부터',
#   '초래',
#   '비상사태는',
#   '교통시스템',
#   '에서의',
#   '혼란',
#   '이르렀다',
#   '낮은',
#   '가시',
#   '성',
#   '때문',
#   '항공',
#   '사들이',
#   '비행을',
#   '취소하도록',
#   '강요',
#   '하며'],
#  ['유럽연합',
#   '사는',
#   '영국시민',
#   '과',
#   '영국',
#   '사는',
#   '유럽연합',
#   '시민',
#   '신분',
#   '과',
#   '권리',
#   '주된',
#   '관심사',
#   '이다'],
#  ['지나', '고', '나서', '보면', '그것', '대게', '분명', '해', '보인다'],
#  ['그들', '또한', '지진', '힘과', '강도를', '측정', '한다'],
#  ['그들',
#   '어떻게',
#   '지구',
#   '형성',
#   '되는지',
#   '어떻게',
#   '오늘날',
#   '그것',
#   '움직',
#   '이는지에',
#   '대해',
#   '화산',
#   '드러',
#   '낼',
#   '있는것을',
#   '알기를',
#   '원한다'],
#  ['다른', '파충류들처럼', '그들', '냉혈동물', '이고', '그들', '온도', '환경', '과', '함께', '변한다'],
#  ['12살아들과', '나는', '여행', '후에', '집에', '돌아', '온', '중이었다'],
#  ['싱크대',
#   '위의',
#   '창문',
#   '들은',
#   '부서져서',
#   '수백',
#   '유리',
#   '조각들은',
#   '내',
#   '부엌',
#   '바닥',
#   '엉망',
#   '으로',
#   '만들었다'],
#  ['두번째', '그들', '깨물수', '없다'],
#  ['윌리엄셰익스피어는',
#   '400년',
#   '전보다',
#   '더',
#   '전에',
#   '살았기',
#   '때문',
#   '애초에',
#   '그시대의',
#   '많은',
#   '기록',
#   '들이',
#   '잃어버리고',
#   '존재',
#   '하지',
#   '않아',
#   '서',
#   '우리',
#   '그의',
#   '사람',
#   '모든것을',
#   '알지',
#   '못한다'],
#  ['무슬림사회에서',
#   '그',
#   '제스처',
#   '일종',
#   '모욕',
#   '주는',
#   '행위',
#   '중',
#   '가장',
#   '나쁜것으로',
#   '고려',
#   '되어졌다'],
#  ['4월', '라임', '평균', '도매가는', '56센트', '였는데', '작년', '가격', '2배', '이다'],
#  ['그것', '실체', '있고', '정의', '되며', '측정', '가능', '하다'],
#  ['어떤', '종류', '스프를', '살지', '선택', '해라'],
#  ['75000달러의', '의미', '무엇', '인가'],
#  ['몇몇', '회사', '들은', '그들', '직원', '에게', '카페테리아', '장려', '프로그램', '제공', '한다'],
#  ['컴퓨터', '사용', '자의', '심리', '관여하고', '반응', '유발', '하는', '경험', '만든다'],
#  ['그들',
#   '예술',
#   '표현',
#   '항상',
#   '묘사',
#   '되는',
#   '사물',
#   '설명하고',
#   '다듬고',
#   '명화하게',
#   '만들고',
#   '있다는',
#   '것을',
#   '안다'],
#  ['바다', '뱀들을', '지구상', '독성이', '강한', '생명체', '들중에', '속한다'],
#  ['갈색',
#   '알약',
#   '0',
#   '3그램',
#   '이고',
#   '80퍼센트',
#   '차와',
#   '20퍼센트의',
#   '차',
#   '맛으로',
#   '구성',
#   '돼',
#   '있다'],
#  ['그',
#   '기술',
#   '을은',
#   '인터넷',
#   '서버가',
#   '개인들',
#   '웹브라우저',
#   '안에',
#   '저장',
#   '하는',
#   '작은파일인',
#   '쿠키',
#   '에의해',
#   '가능',
#   '하게',
#   '된다',
#   '그것',
#   '기억할수',
#   '있도록'],
#  ['나중에',
#   '너의',
#   '아빠',
#   '너의',
#   '남동생의',
#   '자폐증에',
#   '대해',
#   '알게',
#   '됐을때',
#   '그는',
#   '내가',
#   '잊지',
#   '못할',
#   '한가지',
#   '말했다'],
#  ['가르', '치는', '것은', '오늘날', '작가들', '생계를', '꾸리는', '일반적', '방법', '이다'],
#  ['일', '경험', '일까'],
#  ['흡연이', '직접적', '폐암의', '원인', '이라고', '입증되었다'],
#  ['가장', '덜', '보수적', '사람들'],
#  ['자격',
#   '있는',
#   '투표자',
#   '영국',
#   '아일랜드인',
#   '그리고',
#   '영국',
#   '살고있는',
#   '18세',
#   '이상',
#   '영연방',
#   '시민',
#   '이었다'],
#  ['탈퇴를', '협상', '하는', '것은', '약', '2년', '필요', '것이다'],
#  ['우리', '그에', '대해', '모든것을', '알기', '때문'],
#  ['중국',
#   '무술에',
#   '뿌리',
#   '둔',
#   '태극권은',
#   '몸을',
#   '운동',
#   '시키고',
#   '마음을',
#   '진정',
#   '시키기',
#   '위해서',
#   '일련의',
#   '느리고',
#   '흐르는',
#   '듯한',
#   '움직임',
#   '과',
#   '깊고',
#   '느린',
#   '호흡을',
#   '사용',
#   '한다'],
#  ['당신', '춤을', '향상', '시키는', '최고의', '방법'],
#  ['완은', '또한', '가야금의', '소리', '어떤', '다른', '현악기에서', '모방', '될', '없다고', '설명', '했다'],
#  ['그녀', '물었다'],
#  ['대부분', '지질학', '자들은', '특정', '분야', '에서', '전공', '한다'],
#  ['연구분야',
#   '밀접하게',
#   '집중',
#   '하는',
#   '것은',
#   '지질학',
#   '자들이',
#   '상세한',
#   '지식',
#   '얻도록',
#   '허락',
#   '한다'],
#  ['그들', '지진', '발생', '하기', '전에', '표면아래', '에서', '무엇', '발생', '하는지의', '증거', '찾는다'],
#  ['무엇', '지질학', '인가'],
#  ['대신',
#   '그것',
#   '운이',
#   '좋은',
#   '사람들',
#   '생각',
#   '하고',
#   '행동',
#   '하는',
#   '방법',
#   '결과',
#   '이다',
#   '그런데',
#   '그것',
#   '운이',
#   '좋아',
#   '지는',
#   '것을',
#   '누구',
#   '든',
#   '배울',
#   '있다는',
#   '것을',
#   '의미',
#   '한다'],
#  ['당신', '심지어', '몇몇', '굉장', '새로운', '친구들', '사귈', '있다'],
#  ['보통',
#   '식료품점',
#   '만개',
#   '아이템',
#   '옮겨져있지만',
#   '너는',
#   '그것들',
#   '대부분',
#   '찾을',
#   '있다고',
#   '빨리',
#   '나에게',
#   '말할',
#   '있다'],
#  ['베블런', '따르면', '이런', '상품들', '높은', '지위를', '나타내야', '한다'],
#  ['다른',
#   '마음들',
#   '모으고',
#   '저장하고',
#   '정보',
#   '분석',
#   '하는',
#   '것에',
#   '반대',
#   '하여',
#   '공격',
#   '하고',
#   '방어',
#   '하는',
#   '것은',
#   '잘하는',
#   '같지만',
#   '조금',
#   '창조적',
#   '이지',
#   '않다'],
#  ['지금', '현대시간', '에서는', '사람들', '익스트림', '스포츠', '사랑', '한다'],
#  ['이건은', '판크라티온', '으로', '극단적', '레슬링', '과', '복싱', '혼합물', '이다'],
#  ['사건', '에서는', '오직', '2개의', '규칙', '만이', '적용', '된다'],
#  ['많은', '측정', '치의', '총계는', '더', '포괄적인', '상황', '제공', '것이다'],
#  ['그러므로', '갑작', '스런', '미끄러움과', '다음', '사고', '위험', '있다'],
#  ['운전', '안전', '보장', '하기', '위해', '차를', '타기전에', '검사', '하는', '것이', '최선', '이다'],
#  ['기본적',
#   '으로',
#   '실수',
#   '절대',
#   '만들지',
#   '않는',
#   '사람들',
#   '우연',
#   '실수',
#   '만드는',
#   '사람',
#   '보다',
#   '덜',
#   '매력적',
#   '이거나',
#   '덜',
#   '호감',
#   '적으로',
#   '인식',
#   '된다'],
#  ['경우', '에도', '공은', '네트', '통과', '했고', '점수판은', '2점', '늘었다'],
#  ['그는', '암때문에', '1880년에', '그의', '집에서', '죽었다'],
#  ['대부분', '작가들', '이중생활을', '한다'],
#  ['소비자들',
#   '온라인',
#   '조사',
#   '뉴스기사',
#   '보기',
#   '친구',
#   '와',
#   '대화',
#   '전문가',
#   '와',
#   '상담함으로써',
#   '정보',
#   '모을',
#   '있다'],
#  ['지나', '치게', '많은', '정보', '스트레스', '야기'],
#  ['기후',
#   '더',
#   '상승',
#   '수록',
#   '아프리카',
#   '와',
#   '같은',
#   '지역',
#   '농산물',
#   '생산',
#   '감소',
#   '직면하고',
#   '충분',
#   '식량',
#   '생산',
#   '하느라',
#   '애쓸것이다',
#   '그들',
#   '수출',
#   '아마',
#   '떨어질',
#   '것이다'],
#  ['당연', '히', '넌', '할수', '있다'],
#  ['이때',
#   '까지',
#   '보존',
#   '음식',
#   '일부',
#   '테스트',
#   '되었고',
#   '프랑스',
#   '해군은',
#   '음식',
#   '질에',
#   '감동',
#   '받았다'],
#  ['공급', '과수요의', '법칙', '더이상', '작용', '하지', '않는다'],
#  ['바닷가재', '더', '싸지면', '레스토랑은', '그것', '가격', '내릴', '것이다'],
#  ['넌', '늙은', '개에게', '새로운', '재주를', '가르칠수', '없다'],
#  ['일리엇은', '은행원이었다가', '출판', '업자가', '되었다'],
#  ['다른', '작가들은', '가르', '쳤다', '교사'],
#  ['침팬지', '수행', '인간아이', '와', '비교', '될때', '원시적', '으로', '보인다'],
#  ['인간', '과', '침팬지', '언어', '유사성'],
#  ['많은',
#   '사람들',
#   '그들',
#   '생각',
#   '나누는데',
#   '너무',
#   '집중',
#   '그들',
#   '메세지가',
#   '어떻게',
#   '받아들여지는지',
#   '말하는것',
#   '좋은',
#   '생각',
#   '인지에',
#   '대해',
#   '생각',
#   '하는',
#   '것을',
#   '잊는다'],
#  ['배우는것이', '중요', '하다고', '생각', '해야한다'],
#  ['많은', '바다뱀', '들은', '포식자들', '에게', '경고', '함으로써', '문제', '해결', '한다'],
#  ['영국', '유럽', '떠날', '가능성', '브렉시트', '알려졌다'],
#  ['투표', '후에', '유로의', '가치', '올랐다'],
#  ['복잡',
#   '사회',
#   '와',
#   '기술적',
#   '변화',
#   '들을',
#   '포함',
#   '하는',
#   '지역',
#   '에서',
#   '성공적',
#   '예측',
#   '위한',
#   '방법',
#   '없다',
#   '그런데',
#   '그곳',
#   '에서',
#   '많은',
#   '요인',
#   '결정',
#   '하는',
#   '것은',
#   '알려지지',
#   '않았고',
#   '어떤사건에서',
#   '확실',
#   '하게',
#   '어떤',
#   '단일',
#   '그룹',
#   '통제',
#   '아래',
#   '있지',
#   '않았다'],
#  ['세계적',
#   '초연결',
#   '과',
#   '체계',
#   '통합은',
#   '수입',
#   '교육',
#   '혁신',
#   '기술',
#   '에서',
#   '엄청',
#   '난',
#   '이익',
#   '으로',
#   '이끌어왔다'],
#  ['그러나',
#   '양자역학',
#   '포함',
#   '엄청',
#   '난',
#   '방식',
#   '으로',
#   '이결론을',
#   '수정한다',
#   '그리고',
#   '호킹',
#   '블랙홀',
#   '양자역학',
#   '적으로',
#   '복사열을',
#   '방출',
#   '한다는',
#   '것을',
#   '발견',
#   '했다'],
#  ['나이게', '수업', '매우', '유용', '합니다'],
#  ['난',
#   '주로',
#   '전통적',
#   '중국음악',
#   '공부',
#   '했기',
#   '때문',
#   '전통적',
#   '한국음악',
#   '과',
#   '중국음악',
#   '비교',
#   '하는',
#   '것은',
#   '흥미',
#   '롭다',
#   '그곳',
#   '에는',
#   '전통적',
#   '한국음악',
#   '실제',
#   '남아',
#   '있고',
#   '중국음악',
#   '에서',
#   '더이상',
#   '발견',
#   '없는',
#   '몇몇',
#   '요소',
#   '들이',
#   '있기',
#   '때문'],
#  ['많은',
#   '예술',
#   '가들은',
#   '오직',
#   '그들',
#   '그들',
#   '자신',
#   '노력',
#   '홀로',
#   '집중',
#   '있을',
#   '때',
#   '일할',
#   '수있다',
#   '그리고',
#   '많은',
#   '이들',
#   '그들',
#   '완성',
#   '되지',
#   '않은',
#   '작품',
#   '보여주는',
#   '것을',
#   '거절',
#   '한다'],
#  ['행운', '당신', '에게', '더', '가까운', '관계', '가져온다'],
#  ['만약',
#   '당신',
#   '상황',
#   '대한',
#   '당신',
#   '혐오',
#   '감을',
#   '비언어적',
#   '으로',
#   '언급',
#   '하기를',
#   '원한다면',
#   '코의',
#   '주름',
#   '또는',
#   '올라간',
#   '당신',
#   '윗입술이',
#   '당신',
#   '메세지를',
#   '이해',
#   '시킬',
#   '것이다'],
#  ['잠재노출',
#   '로서',
#   '알려진',
#   '그런',
#   '짧은',
#   '노출',
#   '지속',
#   '에서',
#   '사람들',
#   '자극',
#   '기록',
#   '없다',
#   '그리고',
#   '따라서',
#   '참가',
#   '자들은',
#   '표의문자',
#   '본',
#   '것을',
#   '기억',
#   '거라고',
#   '기대',
#   '되지',
#   '않았다'],
#  ['또',
#   '다른',
#   '행동',
#   '옵션',
#   '큰',
#   '소리',
#   '내고',
#   '껍질을',
#   '통해',
#   '후퇴하고',
#   '촘촘한',
#   '볼을',
#   '구르고',
#   '땅처럼',
#   '포식자',
#   '없는',
#   '지역',
#   '선택',
#   '사는',
#   '혹은',
#   '단체로',
#   '살면서',
#   '많은',
#   '안전',
#   '의지',
#   '하는',
#   '것을',
#   '포함',
#   '한다'],
#  ['내가', '불을', '켜기전에', '집이', '놀라울정도로', '춥다는것을', '깨달았다'],
#  ['고대', '올림픽', '약한사람은', '제거하고', '강한사람에게는', '영광을', '주기', '위하여', '계획', '되어있다'],
#  ['하지만',
#   '우리',
#   '그의',
#   '정확',
#   '생일',
#   '모르지만',
#   '적어도',
#   '그날',
#   '보다',
#   '며칠',
#   '전에',
#   '태어',
#   '났음에',
#   '틀림',
#   '없다'],
#  ['한국',
#   '과',
#   '이집트',
#   '와',
#   '같은',
#   '일부',
#   '문화',
#   '에서는',
#   '공손',
#   '함의',
#   '표준',
#   '으로',
#   '누군가',
#   '먹는것이나',
#   '마시는것',
#   '같은',
#   '어떤것을',
#   '주었을때',
#   '첫번째',
#   '반드시',
#   '거절',
#   '해야한다고',
#   '요구',
#   '한다'],
#  ['왜냐하면',
#   '대부분',
#   '장소',
#   '에서는',
#   '이러한',
#   '표준',
#   '유효화되어있지않고',
#   '거식증',
#   '미국',
#   '밖에서는',
#   '만연하지',
#   '않다'],
#  ['게다가', '식욕부진증은', '꽤', '최근', '장애', '이다'],
#  ['개들은', '움직임', '더', '예민', '하지만', '우리', '보는', '부분', '75퍼센트만', '본다'],
#  ['그들',
#   '에게',
#   '너의',
#   '감정',
#   '솔직하게',
#   '하고',
#   '너',
#   '스스로',
#   '책임',
#   '으로부터',
#   '벗어',
#   '나고',
#   '휴식을',
#   '취할',
#   '기회',
#   '가져라'],
#  ['몇', '지식', '들은', '일반적', '이며', '그', '지식', '많은', '다양', '상황', '적용', '된다'],
#  ['그곳', '세계', '최초', '대학', '이였다'],
#  ['면역체계', '너무', '복잡', '그것', '설명', '하기', '위해서는', '책', '권이', '필요', '정도', '다'],
#  ['좋은', '감정', '안', '좋은', '감정', '으로', '변했다'],
#  ['그는', '시의', '모든', '것을', '잊었지만', '복사본을', '가지고', '있지', '않았다'],
#  ['그것', '사람', '기본', '필요', '충족', '적절', '하다고', '여겨지는', '수입', '으로', '나타', '난다'],
#  ['누군가', '그들', '요구', '따라', '부가적인', '생명', '보험', '의료', '혜택', '구매', '지도', '모른다'],
#  ['우리', '문화', '에서', '슬픔', '종종', '필요', '없고', '원하지', '않는', '감정', '이다'],
#  ['보존', '자연서식지', '보호', '포함', '한다'],
#  ['해변', '들은', '폐쇄', '됐다'],
#  ['그', '조언', '들은', '너가', '12월', '방학을', '해변', '에서', '보내라는것은', '아니다'],
#  ['광고', '티비시청자에게는', '소음'],
#  ['17살때',
#   '그녀',
#   '여자',
#   '들을',
#   '위한',
#   '자신',
#   '만의',
#   '학교',
#   '열어서',
#   '과학과',
#   '수학을',
#   '가르',
#   '쳤다'],
#  ['그녀', '망원경을', '통해', '혜성', '발견', '했을때', '미국', '천문학의', '중심', '으로', '급부상했다'],
#  ['반면에',
#   '이성',
#   '이해',
#   '하는것을',
#   '목적',
#   '으로',
#   '두고',
#   '무엇',
#   '표면아래',
#   '있는지',
#   '알아',
#   '내려고',
#   '한다'],
#  ['블라인드',
#   '테스트',
#   '에서는',
#   '비싸지않은',
#   '와인',
#   '선호',
#   '하지만',
#   '실제',
#   '사람들',
#   '비싼',
#   '와인',
#   '마시는',
#   '것에서',
#   '기쁨',
#   '얻는다'],
#  ['그것', '중의', '일부', '우박', '으로', '얼지도', '모른다'],
#  ['콜라비', '섬유', '비타민', '비타민', '칼륨', '칼슘', '함유', '한다'],
#  ['그후', '다른선생님들', '과', '식사', '했다'],
#  ['늙은개에게', '새로운', '재주를', '가르', '칠', '없다고', '종종', '말한다'],
#  ['난', '그가', '2년', '동안', '알', '필요가', '있는', '모든것을', '가르', '쳐줄', '것이다'],
#  ['재밌고', '유머러스한'],
#  ['다른', '사람들은', '조직', '칭찬', '했다'],
#  ['직업', '얻기위해', '유쾌한', '사람', '되라'],
#  ['침팬지', '보호', '필요성'],
#  ['그것', '우리', '뇌간이', '영역', '으로', '변연계로', '대뇌', '피질로', '둘러', '쌓여있는', '이유이다'],
#  ['이것',
#   '1974년',
#   '호킹',
#   '정말',
#   '놀라운',
#   '어떤',
#   '것을',
#   '발견',
#   '했을',
#   '때까지',
#   '사실',
#   '이었다'],
#  ['호킹', '블랙홀', '완전', '히', '검지', '않다고', '발표', '했다'],
#  ['양자세계의', '미스테리'],
#  ['일반적', '상대성의', '탄생'],
#  ['단순',
#   '노출',
#   '효과',
#   '초기',
#   '논증에서',
#   '실험',
#   '에서의',
#   '참가',
#   '자들은',
#   '일본어',
#   '로부터',
#   '일련의',
#   '알파벳',
#   '노출',
#   '되었다'],
#  ['움직',
#   '이지',
#   '않는',
#   '것처럼',
#   '행동',
#   '공격',
#   '막는데',
#   '도와줄',
#   '있는데',
#   '그러나',
#   '반면에',
#   '근육',
#   '어는',
#   '것은',
#   '싸움',
#   '혹은',
#   '나는',
#   '데',
#   '사용',
#   '되는',
#   '포즈와',
#   '대조적',
#   '이다',
#   '토닉',
#   '멈춤',
#   '있어서',
#   '몸의',
#   '근육',
#   '유연',
#   '해진다'],
#  ['내가', '너에게', '달걀', '어디', '있냐고', '나에게', '말해라고', '하면', '너는', '그렇게', '있니'],
#  ['가격',
#   '더이상',
#   '더',
#   '많이',
#   '충분',
#   '하게',
#   '적어져서',
#   '덜',
#   '부유',
#   '사람들',
#   '살',
#   '있다면',
#   '부자들은',
#   '사는',
#   '것을',
#   '멈출거다'],
#  ['블라인드',
#   '테스트',
#   '에서',
#   '저렴',
#   '한게',
#   '선호',
#   '되었으나',
#   '그들',
#   '비싼',
#   '와인',
#   '마시는',
#   '것이',
#   '더',
#   '기쁘다는',
#   '것을',
#   '보여주었다'],
#  ['환경문제', '다루는', '2가지', '방식', '보존', '그리고', '복원', '이다'],
#  ['보존', '방법', '현존하는', '서식지', '보호', '하는', '것을', '포함', '한다'],
#  ['서식지', '보호', '생태계', '파과로부터', '생기는', '환경', '이슈를', '막는다'],
#  ['그녀', '그녀', '창문', '에서', '비가', '천천히시들해지기', '시작', '하는', '것을', '내려다', '보았다'],
#  ['마음은', '본질적', '으로', '생존', '본능적인', '기계', '이다'],
#  ['게다가', '우리', '어떻게', '그들', '여성', '분들이', '선택', '되었는지', '말하지', '못했다'],
#  ['스포츠',
#   '카의',
#   '배터리',
#   '힘은',
#   '12만달러에',
#   '팔리고',
#   '최고속도는',
#   '시간',
#   '당',
#   '200',
#   '이며',
#   '스피드킹',
#   '처음',
#   '나온',
#   '이후',
#   '깨끗',
#   '기술',
#   '흥미',
#   '롭다'],
#  ['아리스탄느', '수백', '만달러를', '절약하고', '동시에', '환경', '개선했다'],
#  ['모든', '창조', '습지', '들은', '인간', '과', '야생동물들에게', '유용', '하다'],
#  ['미국',
#   '영어',
#   '에서',
#   '칭찬',
#   '하는',
#   '태도',
#   '대한',
#   '연구',
#   '에서',
#   '조사',
#   '다들은',
#   '발견',
#   '했다',
#   '대부분',
#   '중요',
#   '미국',
#   '영어',
#   '칭찬',
#   '특징',
#   '중',
#   '하나는',
#   '거의',
#   '전체적',
#   '으로',
#   '독창성',
#   '부족',
#   '하다'],
#  ['하지만', '대부분', '사람들', '행동', '매우', '다르다'],
#  ['미국',
#   '멕시코',
#   '에서',
#   '라임',
#   '97프로를',
#   '가져오는데',
#   '나쁜날씨와',
#   '질병',
#   '결합',
#   '으로',
#   '공급',
#   '폭락',
#   '과',
#   '가격',
#   '폭등을',
#   '겪었다'],
#  ['그', '결과', '약한', '면역체계', '감염', '이끌고', '면역체계', '와', '저항', '력을', '손상', '시킨다'],
#  ['기질', '속성', '으로', '도약하는', '것이', '훨씬', '쉽다'],
#  ['그는', '인파', '사이', '에서', '아빠', '찾으려', '했으나', '없었다'],
#  ['그는', '그의', '다리', '움직', '일', '없다고', '생각', '했다'],
#  ['카페테리아', '장려금', '다양', '형태', '가진다'],
#  ['그는',
#   '자동차',
#   '좋아',
#   '하고',
#   '회사',
#   '좋아',
#   '하고',
#   '그',
#   '회사',
#   '주식',
#   '소유',
#   '하는',
#   '것을',
#   '좋아',
#   '한다는',
#   '직관을',
#   '들었다'],
#  ['아프리카',
#   '미국인',
#   '부모',
#   '들은',
#   '그들',
#   '자식들에게',
#   '호박파이',
#   '고구마파이와',
#   '같다',
#   '라고',
#   '말하며',
#   '설명',
#   '한다'],
#  ['프로젝트',
#   '장애',
#   '대한',
#   '대화',
#   '쌓고',
#   '더',
#   '나은',
#   '접근성과',
#   '결과',
#   '추진하는',
#   '것이',
#   '중점이다'],
#  ['여러',
#   '사람들',
#   '의해진',
#   '친절',
#   '과',
#   '관대',
#   '함이',
#   '와',
#   '그의',
#   '가족들',
#   '에게',
#   '큰',
#   '차이',
#   '가져왔다'],
#  ['이런', '의미', '2번째', '슛', '또한', '완벽', '했다'],
#  ['계절', '마다', '회사', '로부터', '더', '종자', '사도록'],
#  ['너가',
#   '좋아',
#   '하는',
#   '방법',
#   '빨고',
#   '씹고',
#   '물에',
#   '타먹는',
#   '여전히',
#   '너가',
#   '진짜',
#   '컵에',
#   '차를',
#   '마시는',
#   '기분',
#   '느끼게',
#   '할것이다',
#   '라고',
#   '그들',
#   '말했다'],
#  ['유명',
#   '소비재',
#   '로선에서부터',
#   '소금',
#   '까지를',
#   '판매',
#   '하는',
#   '수익성',
#   '좋은',
#   '사업',
#   '아프리카',
#   '와',
#   '인도',
#   '지었다'],
#  ['우리', '우리', '아이들', '많은', '정보', '기억', '하도록', '어떻게', '가르칠수', '있을까'],
#  ['우리', '장르', '와', '화가', '탐구하고', '세부사항', '자세', '히', '보기위해', '확대할수', '있다'],
#  ['사라지는', '갤러리', '와', '박물관', '비밀'],
#  ['제미슨은', '1993년에', '나사', '떠남'],
#  ['상받은', '작가', '미시간에서', '태어', '났고', '위스콘신에서', '자랐다'],
#  ['정부', '그산업에', '관여', '하기', '시작', '한다'],
#  ['가치', '있는', '것을', '생산', '하는', '것은', '수년간', '보람없는', '노동', '요구', '할지도', '모른다'],
#  ['바닷가재', '더', '조금', '일', '수록', '가격', '더', '높아진다'],
#  ['기류', '다시', '위쪽으로', '바뀔지도', '모르고', '구름안에서', '그비를', '휘젓게', '만들지도', '모른다'],
#  ['상승', '하는', '온도', '영향', '미래', '위해', '기다리지', '않는다'],
#  ['열기는',
#   '빙하',
#   '와해빙을',
#   '녹일',
#   '뿐만',
#   '아니라',
#   '강수',
#   '량',
#   '패턴',
#   '변화',
#   '시키고',
#   '동물들',
#   '이동',
#   '하게',
#   '만듬'],
#  ['깃털', '같은', '새들이', '함께', '모인다'],
#  ['사실', '둘다', '아니다'],
#  ['이것',
#   '어린사람',
#   '들이',
#   '범죄',
#   '적인활동에',
#   '포함',
#   '되는것을',
#   '막는',
#   '교육적',
#   '이고',
#   '사회적',
#   '프로그램',
#   '발전',
#   '시키는것을',
#   '의미',
#   '하거나',
#   '거리',
#   '더많은',
#   '경찰',
#   '들을',
#   '두는것을',
#   '의미',
#   '한다'],
#  ['예방', '치료', '보다', '낫다'],
#  ['학교',
#   '와',
#   '회사',
#   '닫혔고',
#   '베이징',
#   '도시정부는',
#   '사람들',
#   '집안에있게',
#   '공기',
#   '청정기를',
#   '작동',
#   '시키게',
#   '실내활동',
#   '줄이게',
#   '경고',
#   '했다'],
#  ['이것', '세계', '놀라게', '했다'],
#  ['우리', '우리', '가족', '위해', '집안일을', '한다'],
#  ['그들',
#   '실제표현',
#   '보다',
#   '더',
#   '긴',
#   '또는',
#   '더',
#   '짧은',
#   '시간동안',
#   '유지',
#   '된다는',
#   '점',
#   '오직',
#   '얼굴',
#   '일부분',
#   '만',
#   '사용',
#   '한다는',
#   '점에서',
#   '실제',
#   '정서',
#   '표현',
#   '과',
#   '다르다'],
#  ['모든사람들이',
#   '반복',
#   '으로',
#   '인한',
#   '기억',
#   '통해서',
#   '많은',
#   '정보',
#   '저장하고',
#   '조정하고',
#   '기억',
#   '하기',
#   '위해서',
#   '만들어',
#   '진',
#   '뇌와',
#   '함께',
#   '잠재적',
#   '천재',
#   '라는',
#   '것을',
#   '너에게',
#   '증명',
#   '해볼게'],
#  ['가게',
#   '분류',
#   '별로',
#   '나뉘어져',
#   '나열',
#   '되어있다',
#   '그리고',
#   '너는',
#   '반복적',
#   '으로',
#   '그',
#   '가게',
#   '에서',
#   '쇼핑',
#   '해왔다'],
#  ['다른',
#   '말로',
#   '말하면',
#   '너는',
#   '반복',
#   '나열',
#   '아이템',
#   '봐왔고',
#   '분류',
#   '정렬',
#   '너가',
#   '가게',
#   '전체적',
#   '그림',
#   '쉽게',
#   '기억',
#   '하게',
#   '만든다'],
#  ['전세계적',
#   '조사',
#   '에서',
#   '놀라운',
#   '결론',
#   '미국',
#   '에서',
#   '가장',
#   '유명',
#   '수학자들중',
#   '아인슈타인',
#   '포함',
#   '그들',
#   '일하는',
#   '방식',
#   '에서',
#   '오직',
#   '간결하게',
#   '종속',
#   '적인',
#   '역할',
#   '하고',
#   '창조적',
#   '활동',
#   '자체',
#   '결정적',
#   '부분',
#   '이라는',
#   '생각',
#   '이라는',
#   '것을',
#   '발견',
#   '했다'],
#  ['오직', '강하고', '제일', '단단', '운동선수', '만이', '시합', '한다'],
#  ['이것',
#   '대부분',
#   '치과의사',
#   '들이',
#   '웃는',
#   '칫솔',
#   '다른',
#   '브랜드',
#   '보다',
#   '선호',
#   '하는',
#   '것이라고',
#   '말하는것',
#   '처럼',
#   '보인다'],
#  ['하지만', '제공', '증거', '중에', '50대여성중에', '76퍼센트만이라는', '것이', '동의', '것이다'],
#  ['불행',
#   '히도',
#   '어떤',
#   '광고',
#   '들은',
#   '꽤',
#   '전형적',
#   '이고',
#   '소비자들',
#   '광고',
#   '들의',
#   '요구',
#   '진지하게',
#   '받아들이는',
#   '것을',
#   '피하고',
#   '단지',
#   '우리자신',
#   '만의',
#   '판단',
#   '사용',
#   '해야',
#   '한다'],
#  ['미국인',
#   '과',
#   '캐나다인들은',
#   '예를',
#   '들어',
#   '합당한',
#   '변명',
#   '동반',
#   '하여',
#   '거절',
#   '해주기를',
#   '기대',
#   '한다'],
#  ['비록',
#   '복사기가',
#   '누구',
#   '나',
#   '쉽게',
#   '사용할수',
#   '있게',
#   '만들었지만',
#   '그들',
#   '복합한',
#   '특징',
#   '과',
#   '인터페이스는',
#   '좌절하게만든다'],
#  ['인도',
#   '인구',
#   '다양',
#   '비율',
#   '오직',
#   '필요',
#   '영양분의',
#   '80프로만',
#   '채워지는',
#   '식사',
#   '겨우',
#   '연명해가는',
#   '시골사람들',
#   '구성',
#   '되어진다'],
#  ['빠르고',
#   '더효율적인',
#   '기술',
#   '더',
#   '증가',
#   '효율',
#   '늘어',
#   '나는것은',
#   '이미지',
#   '찾는데',
#   '사용',
#   '하기',
#   '때문',
#   '이다'],
#  ['나는',
#   '어떻게',
#   '여자',
#   '들을',
#   '위한건지',
#   '또는',
#   '다른',
#   '남자',
#   '들을',
#   '위한건지',
#   '모르겠다',
#   '하지만',
#   '내가',
#   '어렸을때',
#   '나는',
#   '결혼',
#   '두려워했었다'],
#  ['버스기사',
#   '건설',
#   '기사',
#   '전화기술자',
#   '파일',
#   '럿은',
#   '이제',
#   '많은',
#   '회사',
#   '에서',
#   '관리',
#   '자로서',
#   '여자',
#   '들도',
#   '그들',
#   '수에',
#   '포함',
#   '한다'],
#  ['내년에', '우주', '137억년', '1살이', '되는', '것은', '터무니', '없다'],
#  ['우리', '뇌는', '일상적인', '보다', '인상적인', '결과', '쉽게', '상상', '한다'],
#  ['어떤', '것은', '특정', '주제', '관한', '구체적', '지식', '이다'],
#  ['그녀', '1마일', '떨어져', '보였다'],
#  ['그는', '그의', '직감', '과', '그', '스스로', '그의', '결정', '만족', '것을', '믿었다'],
#  ['초등학교',
#   '선생님',
#   '그녀',
#   '생각',
#   '참고라는',
#   '것을',
#   '사용',
#   '하여',
#   '학생들',
#   '이해',
#   '하도록',
#   '돕는다'],
#  ['호박파이', '와', '친근', '하지', '않은', '학생들', '에게', '간섭의', '근원', '으로', '제공', '있다'],
#  ['이런', '문화적', '작은', '차이', '학생들', '배움에', '영향', '끼친다'],
#  ['그는', '두', '그룹', '에게', '신문', '에서', '사진', '수를', '세라고', '말했다'],
#  ['90살임에도', '1년', '60회', '공연'],
#  ['그결과', '물고기', '와', '식물', '들은', '회복', '됐고', '해변', '다시', '개장했다'],
#  ['시장', '규모가', '워낙', '커서', '여전히', '많이', '번다'],
#  ['계절상품', '판매전략', '변화', '필요성'],
#  ['너가', '어린시절', '했던', '행동', '같은', '것을', '너의', '삶에서', '상상력', '사용', '해라'],
#  ['이웃', '과', '공유', '해라', '너의', '삶의', '즐거움을', '찾은', '방법'],
#  ['소비자들', '위험', '감수해야하는', '것에', '불편', '함을', '느낀다'],
#  ['가상', '작품', '왜', '인기', '있나'],
#  ['1865년', '그녀', '미국', '에서', '최초', '여성', '천문학교수가', '되었다'],
#  ['베블런', '따르면', '그', '상품', '높은', '신분', '나타내야', '한다'],
#  ['가격', '하락은', '판매', '자에게', '판매', '일시적인', '증가', '보이다가', '그후', '떨어질것이다'],
#  ['바닷가재', '저렴', '했으면', '우리', '덜', '먹었을지도', '모른다'],
#  ['지구', '온난화', '증가', '하는', '신호'],
#  ['콜라비', '이상', '모양', '과이름때문에', '사람들', '피하는', '채소', '이다'],
#  ['그들',
#   '그들',
#   '몽골',
#   '고용',
#   '주로부터',
#   '냉혹의',
#   '이야기',
#   '과장',
#   '하도록',
#   '장려',
#   '되는',
#   '것은',
#   '가능',
#   '하다',
#   '그래서',
#   '몽골',
#   '인들은',
#   '그들',
#   '적에게',
#   '더',
#   '위협적으로',
#   '보여졌다'],
#  ['그것',
#   '오늘날',
#   '아마',
#   '가장',
#   '일반적',
#   '해결책',
#   '이고',
#   '모든',
#   '주요대학',
#   '창작과정',
#   '이라',
#   '불리는것을',
#   '제공',
#   '하면서',
#   '소설가와',
#   '시인',
#   '들은',
#   '그',
#   '자리',
#   '안착',
#   '하기위해서',
#   '계속',
#   '싸운다'],
#  ['그러나', '투쟁', '아직', '이기지', '못했다'],
#  ['중국',
#   '거주',
#   '자들',
#   '사이',
#   '격분과',
#   '세계적',
#   '매체의',
#   '정밀',
#   '조사는',
#   '정부',
#   '국가',
#   '공기오염문제',
#   '다루도록',
#   '재촉했다'],
#  ['3천만명이상이', '투표', '했다'],
#  ['어려운', '일은', '어떤', '일이', '실제', '발생', '것인지를', '아는', '것이다'],
#  ['그들', '동굴', '바깥', '에서', '진짜', '사물', '의해', '영감', '받을', '있기', '때문'],
#  ['가장',
#   '중요',
#   '연극',
#   '회사',
#   '에서',
#   '배우',
#   '극작가',
#   '협력',
#   '자로서',
#   '그는',
#   '번영했고',
#   '잘',
#   '알려졌다'],
#  ['반면에',
#   '운이',
#   '안',
#   '좋은',
#   '사람들',
#   '특정',
#   '일에',
#   '긴장하고',
#   '너무',
#   '집중',
#   '되는',
#   '경향이',
#   '있다',
#   '그런데',
#   '그것',
#   '그들',
#   '명쾌하게',
#   '찾지',
#   '못하는',
#   '기회',
#   '알아',
#   '차리게',
#   '하는',
#   '것을',
#   '막는다'],
#  ['그래서',
#   '다음',
#   '당신',
#   '파티에',
#   '향할',
#   '때',
#   '마음에',
#   '있는',
#   '목표',
#   '와',
#   '함께',
#   '가지마라',
#   '아무리',
#   '당신',
#   '누군가',
#   '유혹하기를',
#   '원한다',
#   '할지라도'],
#  ['부모',
#   '세포가',
#   '분열',
#   '때',
#   '그',
#   '결과',
#   '생긴',
#   '두',
#   '개의',
#   '하위',
#   '아메바',
#   '서로',
#   '원래',
#   '부모',
#   '와',
#   '유전적으로',
#   '똑같',
#   '것이다'],
#  ['그는', '시에', '리듬을', '가져온', '국제적', '명성', '첫번째', '미국시인', '중', '한명이다'],
#  ['어떻게', '우리', '아이들', '에게', '많은', '정보', '기억', '하기', '위해서', '가르', '칠', '있을까'],
#  ['그리스', '단어', '판크라티온', '의미', '전체', '힘을', '뜻한다'],
#  ['남자', '금속장식이', '가죽', '끈을', '입는데', '이것', '그들', '적에게', '끔찍', '혼란', '준다'],
#  ['칼리오의',
#   '에인솀',
#   '대학',
#   '문학수업',
#   '강의하는',
#   '동안',
#   '영국',
#   '교수',
#   '그의',
#   '의자',
#   '기대',
#   '어',
#   '그의',
#   '발',
#   '바닥',
#   '놀라는',
#   '교실',
#   '생들에게',
#   '보여주었다'],
#  ['광고', '관해서라면', '우리', '광고', '전달', '해주는', '정보', '판단', '해야한다'],
#  ['그러나',
#   '어떤',
#   '거절',
#   '종종',
#   '다른',
#   '문화',
#   '에서는',
#   '경솔',
#   '함이나',
#   '누군가',
#   '환대를',
#   '거부',
#   '하는걸로',
#   '특히',
#   '어떤',
#   '변명',
#   '없이',
#   '거절',
#   '당해질때에',
#   '여겨진다'],
#  ['우리',
#   '직원들',
#   '관찰',
#   '했는데',
#   '1명',
#   '도움을',
#   '위해',
#   '의지',
#   '하거나',
#   '다른',
#   '이는',
#   '기계',
#   '대해',
#   '더',
#   '많은',
#   '것을',
#   '배우기위해',
#   '지켜보고',
#   '빈곤한',
#   '운영',
#   '대해',
#   '논평',
#   '하는',
#   '사람',
#   '이다'],
#  ['리뷰는', '열광', '적이였지만', '세스타자동차회사는', '재정적위기로', '어려워졌다'],
#  ['데이터',
#   '모을때',
#   '대다수',
#   '데이터',
#   '혼란',
#   '최소화',
#   '하는',
#   '것이',
#   '바람직',
#   '하다고',
#   '생각',
#   '한다'],
#  ['3개',
#   '트렉터',
#   '트레일러와',
#   '다른',
#   '60개',
#   '자동차',
#   '들이',
#   '포함',
#   '연속',
#   '충돌',
#   '사고',
#   '일어',
#   '났다'],
#  ['하나의', '예기치않은상황은', '분류', '하는것이다'],
#  ['성취', '너가', '원하는', '것을', '추구하고', '얻을', '때', '온다'],
#  ['성공', '감정', '또는', '되어있는', '상태', '이다'],
#  ['일반적', '지식', '과', '전문', '지식', '사이', '분명', '선은', '없다'],
#  ['실제', '세계', '에서', '아무도', '혼자', '일하지', '않는', '것이', '진실', '이다'],
#  ['선생님',
#   '학생들',
#   '세대',
#   '열심히',
#   '하지',
#   '않는',
#   '것을',
#   '보았기',
#   '때문',
#   '완고',
#   '하게',
#   '보이며',
#   '그녀',
#   '그들',
#   '스스로',
#   '단련',
#   '되길',
#   '원한다'],
#  ['설명',
#   '적인',
#   '피드백',
#   '아이들',
#   '동기',
#   '부여하고',
#   '목표',
#   '이룰',
#   '있는',
#   '데에',
#   '성적',
#   '보다',
#   '더',
#   '낫다'],
#  ['그는', '그들', '자동차', '만드는', '방법', '안다고', '말했다'],
#  ['인도', '태국', '베트남', '원산', '지이다'],
#  ['너의', '이야기', '그들', '넣음으로써', '아이들', '집중', '얻을', '있음'],
#  ['신화', '이집트', '문화', '에서', '오랜기간동안', '필수적', '부분', '이었다'],
#  ['인도', '차', '과학자들', '씹어먹거나', '뜨거운물', '또는', '찬물에', '녹는', '알약', '생산', '했다'],
#  ['돈이',
#   '별로',
#   '없는',
#   '사람들',
#   '에게',
#   '판매',
#   '함으로써',
#   '돈을',
#   '버는것은',
#   '일어',
#   '날',
#   '거',
#   '같지',
#   '않지만',
#   '회사',
#   '들은',
#   '그것들',
#   '시도',
#   '함으로써',
#   '번성하고',
#   '있다'],
#  ['백화점',
#   '체인',
#   '50억',
#   '달러',
#   '가치',
#   '이상',
#   '유명',
#   '가전제품과',
#   '전자제품',
#   '브라질',
#   '노동자들',
#   '에게',
#   '매년',
#   '팔면서',
#   '수익',
#   '얻는다'],
#  ['감정', '컨트롤', '안되면', '유해하다고', '사람들', '생각'],
#  ['지나', '친', '반복', '창조', '성을', '약하게함'],
#  ['예술', '복제품을', '금지', '해야하나'],
#  ['12살때', '일식의', '순간', '을추정함으로써', '아버지', '도왔다'],
#  ['그녀',
#   '어릴때',
#   '피아노',
#   '치는',
#   '것에',
#   '재능이',
#   '있었고',
#   '그후',
#   '피아니스트',
#   '로서',
#   '훈련',
#   '받았다'],
#  ['그땅이', '이동', '어렵게', '만들었기', '때문', '손님', '과주인관계는', '중요', '하게', '여겨졌다'],
#  ['더', '뜰수있는', '공기', '수증기를', '더', '높은', '고도로', '옮긴다'],
#  ['1인치', '양초', '여전히', '남아', '있었다'],
#  ['우리',
#   '정보',
#   '중',
#   '많은',
#   '부분',
#   '사실',
#   '자주',
#   '과장',
#   '했던',
#   '그',
#   '당시',
#   '기록',
#   '자로부터',
#   '나온다'],
#  ['도시',
#   '진화',
#   '두뇌',
#   '진화',
#   '와',
#   '같다',
#   '그것',
#   '작은',
#   '중심',
#   '으로부터',
#   '발전',
#   '하고',
#   '천천히',
#   '성장하고',
#   '변화',
#   '한다',
#   '그리고',
#   '많은',
#   '오래',
#   '부분',
#   '들이',
#   '여전히',
#   '작동',
#   '하게',
#   '남긴다'],
#  ['그래서',
#   '뒤떨어지고',
#   '때때로',
#   '역효과를',
#   '낳는',
#   '그들',
#   '계속',
#   '헐떡거린다',
#   '그러나',
#   '우리진화',
#   '필요',
#   '결과',
#   '이다'],
#  ['그들', '태양', '빛으로', '그들', '스스로', '끌어', '낼', '있기', '때문'],
#  ['당신',
#   '당신',
#   '균형',
#   '도전',
#   '하기',
#   '위해서',
#   '당신',
#   '체중을',
#   '옮기면서',
#   '팔다리를',
#   '펼치면서',
#   '하나의',
#   '자세',
#   '에서',
#   '다른',
#   '자세',
#   '이동',
#   '한다'],
#  ['악기를',
#   '나에게',
#   '매력적',
#   '으로',
#   '만드는',
#   '당신',
#   '만들',
#   '있는',
#   '너무',
#   '많은',
#   '다른',
#   '소리',
#   '있다'],
#  ['화산',
#   '학자들은',
#   '화산',
#   '연구',
#   '하고',
#   '때때로',
#   '폭발현장에',
#   '그들',
#   '있는',
#   '만큼',
#   '가까이',
#   '있어야',
#   '한다'],
#  ['난', '흥분', '되었고', '들떳기', '때문', '이다'],
#  ['그러나',
#   '내가',
#   '낚시',
#   '함으로써',
#   '지루',
#   '해졌었다고',
#   '생각',
#   '해봐라',
#   '그리고',
#   '나서',
#   '내가',
#   '어떻게',
#   '느꼈을',
#   '것이라고',
#   '생각',
#   '하는가'],
#  ['나는', '7천', '피트의', '고도에서', '그런', '고생', '스러운', '일에', '의해', '지쳤을', '것이다'],
#  ['짧은', '기간', '자극', '기록', '하는', '것은', '불가능', '하다'],
#  ['이러한',
#   '단순',
#   '삶의',
#   '사실',
#   '들은',
#   '수천년동안',
#   '인식',
#   '되어왔고',
#   '부전자전',
#   '이라는',
#   '오래',
#   '속담',
#   '으로',
#   '요약',
#   '되어있다'],
#  ['북반구의', '겨울', '에는', '물이', '사라지고', '얼음', '과', '눈이', '생긴다', '높은산에'],
#  ['그',
#   '적들의',
#   '손가락',
#   '부서지게',
#   '되면서',
#   '얻게',
#   '되는',
#   '그의',
#   '별명을',
#   '사용',
#   '하면서',
#   '손가락',
#   '씨가',
#   '싸우는',
#   '것을',
#   '상상',
#   '해라'],
#  ['그러면',
#   '너가',
#   '나에게',
#   '준',
#   '돈보다',
#   '얼마',
#   '나',
#   '더',
#   '필요',
#   '하던지',
#   '나는',
#   '페루',
#   '있는',
#   '모든',
#   '노예',
#   '들을',
#   '살것이고',
#   '그들',
#   '자유',
#   '롭게',
#   '것이다'],
#  ['만약',
#   '너가',
#   '땅의',
#   '전체',
#   '에서',
#   '하나의',
#   '온도',
#   '감지',
#   '기만',
#   '갖고있다면',
#   '이것',
#   '다른',
#   '것보다',
#   '정확',
#   '해야만',
#   '한다',
#   '그렇지',
#   '않으면',
#   '믿을',
#   '있는',
#   '데이터',
#   '제공',
#   '받기',
#   '힘들다'],
#  ['실제',
#   '검은색',
#   '아니지만',
#   '이것',
#   '실제',
#   '투명하고',
#   '고속도로',
#   '아스팔트',
#   '검정',
#   '이나',
#   '이것',
#   '표면',
#   '통과',
#   '하여',
#   '비추는데',
#   '그러므로',
#   '이것',
#   '검정',
#   '얼음',
#   '이라',
#   '부른다'],
#  ['사람들', '이미지', '찾는데', '광대한', '사용', '한다'],
#  ['그녀', '과거', '비밀', '밝힐', '뿐', '아니라', '현재', '정치', '또한', '견고하게', '다뤘다'],
#  ['자식들의',
#   '성취',
#   '자랑하는',
#   '사람들',
#   '그들',
#   '실패',
#   '불안',
#   '해',
#   '하며',
#   '그들',
#   '수업',
#   '료를',
#   '의식',
#   '한다'],
#  ['그의', '심장', '뛰었다'],
#  ['그녀', '엄마', '딸에게', '그녀', '사과', '중', '하나를', '줄', '있냐고', '물어봄'],
#  ['우리',
#   '유대감',
#   '더',
#   '얻기위해',
#   '그러한',
#   '화면속',
#   '캐릭터들',
#   '의존',
#   '수록',
#   '우리',
#   '뇌는',
#   '그것',
#   '관련되',
#   '어',
#   '있다고',
#   '생각',
#   '한다'],
#  ['디지털',
#   '미디어',
#   '경험',
#   '생물',
#   '학을',
#   '기반',
#   '으로',
#   '하는',
#   '심리학',
#   '과정',
#   '영역',
#   '과',
#   '실리콘을',
#   '기반',
#   '하는',
#   '컴퓨터',
#   '과정',
#   '사이',
#   '독특한',
#   '접점을',
#   '제공',
#   '한다'],
#  ['영화',
#   '제작',
#   '자들은',
#   '여러',
#   '출연진과',
#   '제작',
#   '진의',
#   '도움을',
#   '받아',
#   '영화',
#   '건축물',
#   '끼워',
#   '넣는다'],
#  ['너의', '기억', '말고', '메모를', '믿어라'],
#  ['그것', '덜부유한', '사람들', '제외', '정도', '더이상', '높지', '않다'],
#  ['그림', '천마디의', '말만큼', '가치', '있다는', '속담', '사실', '이다'],
#  ['그러나',
#   '사람들',
#   '온라인',
#   '에서',
#   '뭘하는지',
#   '추척할수있는',
#   '쿠키',
#   '들이',
#   '사생활을',
#   '침해할지도',
#   '모른다고',
#   '제기',
#   '되어왔다'],
#  ['관습은', '법을', '지배', '한다'],
#  ['진화',
#   '아주',
#   '오래',
#   '두뇌',
#   '내부를',
#   '제거',
#   '방법',
#   '없다',
#   '그리고',
#   '그것',
#   '더',
#   '최근',
#   '구조',
#   '어떤',
#   '것으로',
#   '교체',
#   '방법',
#   '없다'],
#  ['그러나',
#   '두개',
#   '시스템',
#   '상대적',
#   '복잡성',
#   '대하나',
#   '일반적',
#   '개념',
#   '뇌의',
#   '중심',
#   '으로',
#   '눈과',
#   '귀를',
#   '연결',
#   '하는',
#   '신경',
#   '크기',
#   '비교',
#   '함에',
#   '따라',
#   '얻어질',
#   '있다'],
#  ['눈의',
#   '신경',
#   '달팽이관',
#   '신경',
#   '보다',
#   '약',
#   '18배',
#   '많은',
#   '뉴런을',
#   '포함',
#   '하기',
#   '때문',
#   '우리',
#   '그것',
#   '적어도',
#   '훨씬',
#   '더',
#   '많은',
#   '정보',
#   '전달',
#   '한다고',
#   '가정',
#   '한다'],
#  ['시간', '위한', '필수조건'],
#  ['그러나',
#   '어떤',
#   '종류',
#   '들은',
#   '예를',
#   '들어',
#   '죽은',
#   '척이라는',
#   '다른',
#   '가능',
#   '옵션',
#   '가지고',
#   '있는데',
#   '그것',
#   '토닉',
#   '멈춤',
#   '이라고',
#   '불리기도',
#   '한다'],
#  ['아이들', '부모', '의해', '가이드', '받지', '못하고', '있다'],
#  ['그는',
#   '스탠포드',
#   '에서',
#   '성장',
#   '했고',
#   '그의',
#   '가족',
#   '가졌고',
#   '재산',
#   '샀지만',
#   '영국',
#   '극장',
#   '중심',
#   '런던',
#   '에서',
#   '일했다'],
#  ['다음',
#   '날',
#   '카리오신문들은',
#   '헤드라인',
#   '학생들',
#   '영국',
#   '인의',
#   '거만을',
#   '비난',
#   '했고',
#   '교수',
#   '반드시',
#   '집에',
#   '가야한다는것을',
#   '요구',
#   '했다'],
#  ['상세한',
#   '조사',
#   '에서',
#   '이것',
#   '발견',
#   '됐다',
#   '모든',
#   '단계',
#   '에서',
#   '규칙',
#   '성이',
#   '존재',
#   '한다는',
#   '것을',
#   '칭찬',
#   '사실',
#   '공식이라는',
#   '것도'],
#  ['그러나',
#   '두드러진',
#   '것은',
#   '오직',
#   '5개의',
#   '형용사',
#   '나이스하고',
#   '좋고',
#   '아름',
#   '답고',
#   '예쁘고',
#   '훌륭한것이',
#   '빈번',
#   '사용',
#   '된다'],
#  ['식욕무질서를',
#   '설명',
#   '하는것을',
#   '시도',
#   '하기위해',
#   '강조하는것',
#   '심리학적',
#   '과',
#   '사회적',
#   '요소',
#   '이다'],
#  ['사실',
#   '알맞게',
#   '반복적',
#   '연속',
#   '적인',
#   '첫번째',
#   '자극',
#   '주관적인',
#   '시간',
#   '적확장이',
#   '유발',
#   '되기에',
#   '충분',
#   '해',
#   '보인다'],
#  ['그런', '다음', '어느', '날', '나는', '제인을', '만났다', '내가', '첫번째', '영상', '촬영', '동안'],
#  ['개인적', '으로', '직업', '수행', '하는', '하는', '기술', '장애물', '없는', '것처럼', '보인다'],
#  ['우리', '너무', '많은', '가능성', '극적', '일들', '붙인다'],
#  ['문자', '소리', '대한', '지식', '읽기', '영역', '에서', '구체적', '이다'],
#  ['개방적',
#   '으로',
#   '소통하지',
#   '않는',
#   '사람들',
#   '그들',
#   '스스로',
#   '발견',
#   '하는',
#   '것을',
#   '힘겨워',
#   '하는',
#   '사람들',
#   '일지도',
#   '모른다'],
#  ['반면', '상황', '따른', '설명', '복잡', '하다'],
#  ['직원들',
#   '그들',
#   '원하는',
#   '보험',
#   '결정',
#   '하지만',
#   '그',
#   '비용',
#   '그들',
#   '보너스',
#   '비용',
#   '으로',
#   '부터',
#   '지원',
#   '되는',
#   '것이다'],
#  ['인식', '오류', '실제', '사람들', '원하는', '것을', '얻게', '이끌어', '주는', '이점', '된다'],
#  ['그에게', '음악', '중요', '했지만', '그는', '화가', '되었다'],
#  ['누구', '더', '빠르게', '습득하고', '누구', '느리게', '습득', '한다고', '제안', '할만한', '증거', '없다'],
#  ['청소', '년들은', '축구', '대한', '유전자', '가지고', '있지', '않다'],
#  ['그가',
#   '5살',
#   '됐을때',
#   '그는',
#   '그의',
#   '어머니',
#   '께서',
#   '연주',
#   '하는',
#   '모든',
#   '노래',
#   '듣고',
#   '모두',
#   '연주',
#   '수있었다'],
#  ['대조적', '으로', '요즘', '이야기', '들은', '덜', '확정적인', '결말'],
#  ['현상', '들이', '새로운', '판과', '개정판', '만들게', '했다'],
#  ['전보다', '화학', '비료를', '더', '사도록'],
#  ['바다뱀', '그들', '먹기위', '해', '스스로', '보호', '하기위해', '독을', '사용', '한다'],
#  ['어린이', '관점', '에서', '행돌을', '이해', '하라'],
#  ['소비자들',
#   '지난번',
#   '샀던',
#   '브랜드',
#   '구입하고',
#   '지난번',
#   '구입',
#   '했던',
#   '것만큼',
#   '만족',
#   '것이라고',
#   '믿음',
#   '으로서',
#   '불확실',
#   '함을',
#   '줄인다'],
#  ['또', '어떤', '소비자들', '안전', '선택', '일어', '나는', '결정규칙', '이용', '지도', '모른다'],
#  ['에서태어나서', '세살때', '시카고', '이주'],
#  ['그이후', '베스트셀러', '소설가가', '되었다'],
#  ['스티븐은', '보험회사', '에서', '일했다'],
#  ['치료법', '발견', '되었음에도', '여전히', '다른', '암들이', '증가하고', '있다'],
#  ['죄수',
#   '동굴',
#   '에서',
#   '풀려났을',
#   '때',
#   '그는',
#   '처음',
#   '태양',
#   '빛으로부터',
#   '고통',
#   '받는다',
#   '그런',
#   '그의',
#   '눈이',
#   '적응',
#   '함에따라',
#   '그는',
#   '진실',
#   '보기',
#   '시작',
#   '한다'],
#  ['플라톤',
#   '그들',
#   '로부터',
#   '숨겨진',
#   '진짜',
#   '실체',
#   '알지',
#   '못한',
#   '채로',
#   '그림',
#   '자동굴에',
#   '감금된',
#   '보통',
#   '사람들',
#   '모습',
#   '묘사',
#   '한다'],
#  ['그러한',
#   '계산',
#   '변형과정',
#   '포함',
#   '뿐만',
#   '아니라',
#   '과학자들',
#   '무엇',
#   '중요',
#   '해야만',
#   '하는지에',
#   '대한',
#   '지식',
#   '부족',
#   '의해',
#   '불리한',
#   '조건',
#   '겪어왔다'],
#  ['사실',
#   '인정',
#   '에대한',
#   '희망',
#   '애초에',
#   '그들',
#   '창조',
#   '하기를',
#   '원하도록',
#   '만드는',
#   '것이다',
#   '그리고',
#   '창조',
#   '과정',
#   '작품',
#   '청중',
#   '발견',
#   '때까지',
#   '끝나지',
#   '않는다'],
#  ['단순',
#   '노출',
#   '결과',
#   '보여주는',
#   '것은',
#   '사람들',
#   '익숙',
#   '자극',
#   '쪽으로',
#   '선호',
#   '발전',
#   '시킨다는',
#   '것이다'],
#  ['눈이', '내려서', '그들', '손과', '발이', '바위어디', '놓아야', '할지', '보이지', '않았다'],
#  ['모든',
#   '진짜',
#   '예술',
#   '가들은',
#   '마음이',
#   '공허한',
#   '장소',
#   '에서부터',
#   '그리고',
#   '내부에',
#   '고요',
#   '함에서',
#   '창조',
#   '한다'],
#  ['하지만', '우리', '어떻게', '조사', '실시', '되는지', '알지', '못하기', '때문', '주의', '해야한다'],
#  ['예를',
#   '들어',
#   '칫솔',
#   '제조업자들은',
#   '포스터',
#   '치과의사',
#   '들의',
#   '80퍼센트',
#   '웃는칫솔을',
#   '추천',
#   '했다고',
#   '썼다'],
#  ['남자',
#   '들은',
#   '간호',
#   '비서업무',
#   '비행승무원',
#   '같은',
#   '전통적',
#   '으로',
#   '여자',
#   '업무라고',
#   '여겨왔던',
#   '직업',
#   '계속',
#   '들어왔다'],
#  ['소음', '8초', '간', '지속'],
#  ['연구',
#   '에서',
#   '사람',
#   '일년에',
#   '75000',
#   '달러를',
#   '벌게되면',
#   '수입',
#   '대한',
#   '감정',
#   '적인',
#   '이익',
#   '없어진다고',
#   '했다'],
#  ['목재', '건조', '되지', '않는', '다면', '물', '아래', '띄어', '운반', '없다'],
#  ['그는', '어려서', '바이올린', '배우고', '어른', '되고', '나서도', '계속', '바이올린', '연주', '했다'],
#  ['운이', '좋은', '사람들', '기회', '잘', '발견'],
#  ['사람들',
#   '어른',
#   '대수적인',
#   '방정식',
#   '풀이를',
#   '알지',
#   '못하면',
#   '우리',
#   '보다',
#   '덜',
#   '지능',
#   '적이다고',
#   '잘못',
#   '추정',
#   '한다'],
#  ['각각', '책은', '다른', '속도', '필요로'],
#  ['자연', '생물학적', '으로', '우리', '올빼미', '에게', '매력', '느끼도록', '준비', '시켰다'],
#  ['1850년',
#   '낭만주의',
#   '시절에',
#   '불은',
#   '덴마크어',
#   '아닌',
#   '노르웨이',
#   '어로',
#   '배우들이',
#   '공연',
#   '하는',
#   '최초',
#   '극장',
#   '공동',
#   '설립',
#   '했다'],
#  ['오늘날', '대부분', '옥수수', '종자들은', '혼종이다'],
#  ['사회',
#   '과학자들은',
#   '경제',
#   '나',
#   '사회발전',
#   '대해',
#   '얘기',
#   '할때',
#   '국민성',
#   '고려',
#   '하지',
#   '않는다'],
#  ['필요', '없는거는', '안사는게', '낫다'],
#  ['감정', '숨길', '필요성'],
#  ['다른', '사람', '감정', '읽기', '어려움'],
#  ['주방정리', '해라', '최고의', '선택', '보기', '쉽고', '접근', '하기', '쉽게'],
#  ['당신', '가게', '에서만', '10000개', '물건들', '분류할수', '있다'],
#  ['대학',
#   '이후',
#   '대학',
#   '으로',
#   '돌아',
#   '오기전에',
#   '미국',
#   '자연역사',
#   '박물관',
#   '에서',
#   '잠시동안',
#   '일했다'],
#  ['제조업자들은', '마켓에', '공급', '하지', '않기', '결심한다'],
#  ['열정', '이없었으면', '아무것도', '이루지', '못햇을것'],
#  ['따뜻', '공기', '상승기류', '폭풍우', '발생', '시킴'],
#  ['비', '내릴때', '공기', '당기고', '기류', '일부', '아래', '돌린다'],
#  ['그', '영향', '지금', '일어', '나고있다'],
#  ['북극', '얼음', '녹아내림'],
#  ['진실', '대한', '인격', '저항'],
#  ['그러나',
#   '다행히',
#   '그녀',
#   '먹은',
#   '저녁',
#   '식사는',
#   '그녀',
#   '피곤',
#   '해지고',
#   '잠들기에',
#   '준비',
#   '되도록',
#   '야기',
#   '했다'],
#  ['엄격'],
#  ['사람들', '범죄율', '낮출', '방법', '대해', '다른', '생각', '갖고있다'],
#  ['연습', '교훈', '보다', '낫다'],
#  ['우리',
#   '뒤돌아',
#   '볼',
#   '때',
#   '각',
#   '사건',
#   '이전',
#   '사건',
#   '으로부터',
#   '명백하고',
#   '논리적으로',
#   '결과',
#   '나오는',
#   '것처럼',
#   '보인다'],
#  ['기술적', '문제들', '다양', '측면', '들을', '빠뜨리다'],
#  ['균형', '위한', '최고의', '운동', '태극권'],
#  ['그들',
#   '암석',
#   '에서',
#   '발견',
#   '증거',
#   '이용',
#   '한다',
#   '그래서',
#   '오래',
#   '전에',
#   '살았던',
#   '동물',
#   '대해',
#   '알았다'],
#  ['대부분', '사람들', '그들', '뱀을', '보았을', '때', '공포', '도망', '가거나', '비명을', '지른다'],
#  ['그들', '피부', '차갑고', '건조', '하다', '심지어', '만지면', '기분', '좋다'],
#  ['당신',
#   '턱을',
#   '떨어뜨리고',
#   '입을',
#   '연채로',
#   '유지',
#   '때',
#   '당신',
#   '깜짝놀랐다고',
#   '말하고',
#   '있을',
#   '지도',
#   '모른다'],
#  ['다른',
#   '놀람의',
#   '특징들',
#   '없이',
#   '커진',
#   '눈은',
#   '말로',
#   '와우',
#   '와',
#   '같은',
#   '목적',
#   '제공',
#   '할지도',
#   '모른다'],
#  ['기간', '연구들', '걸쳐', '확고', '결과', '대한', '책임', '있다'],
#  ['때때로', '영역', '표시', '불편', '하게만든다'],
#  ['이스터',
#   '진정',
#   '해',
#   '그녀',
#   '엄마',
#   '그녀',
#   '딸을',
#   '따라',
#   '무지',
#   '개를',
#   '볼수있는',
#   '창문',
#   '으로가면서',
#   '말했다'],
#  ['어떤시기이후', '갑자기', '문화', '변화', '하기', '시작', '하면서', '걱정', '증가', '했다'],
#  ['심지어',
#   '훌륭한',
#   '과학자들',
#   '창조적',
#   '획기적',
#   '발견',
#   '정신적',
#   '으로',
#   '고요',
#   '함이',
#   '있을때',
#   '왔다고',
#   '보고되었다'],
#  ['한사람당', '약', '350페소', '든다고', '대답', '했다'],
#  ['1980년대',
#   '공공흥미과학센터의',
#   '호사가들은',
#   '미국인',
#   '들이',
#   '전통적',
#   '라드',
#   '버터',
#   '포화지방',
#   '으로',
#   '팜유',
#   '마가린',
#   '과',
#   '쇼트닝',
#   '그',
#   '모든',
#   '것이',
#   '부분적',
#   '으로',
#   '수소화된',
#   '오일',
#   '아이디어',
#   '추진하는것에',
#   '관심',
#   '가졌다'],
#  ['매년',
#   '일을',
#   '찾는것이',
#   '어려우며',
#   '매일',
#   '음식',
#   '사먹는',
#   '것이',
#   '어려운',
#   '많은',
#   '가난한',
#   '사람들',
#   '격일로',
#   '빠르게',
#   '그들',
#   '배고픔을',
#   '관리',
#   '해야만',
#   '한다'],
#  ['뱅갈에서',
#   '가난한사람들의',
#   '식사',
#   '쌀과',
#   '소금',
#   '간이',
#   '되있는',
#   '작은',
#   '콩',
#   '칠리',
#   '몇몇',
#   '양념',
#   '일부',
#   '감자',
#   '와',
#   '녹색',
#   '채소',
#   '차',
#   '그리고',
#   '판',
#   '구장나무의',
#   '잎',
#   '으로',
#   '구성',
#   '되어',
#   '있다'],
#  ['즉',
#   '상당한',
#   '종의',
#   '풍요로움이',
#   '있는',
#   '사회',
#   '더',
#   '기능',
#   '많고',
#   '풍부',
#   '함이',
#   '적은',
#   '종이',
#   '있는',
#   '사회',
#   '보다',
#   '더',
#   '안정',
#   '성이',
#   '있다'],
#  ['미국',
#   '건너',
#   '술집과',
#   '식당',
#   '에서',
#   '그들',
#   '공급',
#   '배급되는',
#   '것은',
#   '알래스카',
#   '항공',
#   '처럼',
#   '라임',
#   '완전',
#   '히',
#   '제거',
#   '되었다'],
#  ['반대', '또한', '사실', '이다'],
#  ['너의',
#   '삶에서',
#   '책임',
#   '대한',
#   '압박감을',
#   '느낀다면',
#   '그',
#   '감정',
#   '균형',
#   '있게',
#   '다룰',
#   '방법',
#   '찾아야',
#   '한다'],
#  ['이러한', '인식', '신체적', '도전', '에서', '또한', '나타', '난다'],
#  ['티크',
#   '밀도',
#   '높아',
#   '수확',
#   '어려움',
#   '있으며',
#   '베어지고',
#   '건조',
#   '되어지지',
#   '않으면',
#   '물에',
#   '가라앉는다'],
#  ['결국', '그에게', '황금', '사과', '줌'],
#  ['아이들', '에게', '이름', '빌리고', '싶다고', '말한', '후', '지원', '자를', '요청', '한다'],
#  ['식민지', '시기', '이후', '도시', '항구', '오염', '물을', '즉각적', '으로', '버렸다'],
#  ['이것',
#   '떨어진',
#   '두명',
#   '독자',
#   '동일',
#   '책을',
#   '논의하고',
#   '비교',
#   '할수있다는',
#   '것을',
#   '의미',
#   '한다'],
#  ['현대',
#   '신경',
#   '과학의',
#   '역사',
#   '많은',
#   '경우',
#   '성인',
#   '뇌는',
#   '손상',
#   '입으면',
#   '고쳐질',
#   '없는',
#   '고정',
#   '구조',
#   '여겨졌다'],
#  ['영국', '모든', '사람들', '투표', '참여', '했다'],
#  ['나는',
#   '며칠',
#   '코랄계곡를',
#   '따라',
#   '낚시',
#   '하면서',
#   '덤불을',
#   '관통하여',
#   '나아',
#   '가면서',
#   '통나무',
#   '넘어',
#   '발을',
#   '헛디디면서',
#   '쓰러진',
#   '나무',
#   '사이',
#   '나아',
#   '가면서',
#   '보냈다',
#   '그러나',
#   '이런',
#   '8시간',
#   '후에도',
#   '나는',
#   '힘들지',
#   '않았다'],
#  ['대신',
#   '그것들',
#   '오는',
#   '대로',
#   '상황',
#   '받아들여라',
#   '그리고',
#   '당신',
#   '무엇',
#   '일어',
#   '날',
#   '지',
#   '절대',
#   '알지',
#   '못한다'],
#  ['두사람은', '경험', '많고', '등산', '떠난', '날', '날씨', '좋았다'],
#  ['연장', '자는', '어린사람', '보다', '더', '비싼', '것을', '고르는', '편이다'],
#  ['그가', '입을', '열었을때', '공기', '밖에', '안나왔다'],
#  ['이긴사람들은', '가장자리', '가려고', '밀어진다'],
#  ['그',
#   '종은',
#   '온화한',
#   '우림',
#   '에서',
#   '호주',
#   '에서',
#   '점점',
#   '더',
#   '마른',
#   '기후',
#   '되면서',
#   '굴복',
#   '되면서',
#   '멸종됐다'],
#  ['저장',
#   '하거나',
#   '수평적',
#   '이거나',
#   '고리의',
#   '관점',
#   '에서',
#   '기억',
#   '묘사',
#   '하는것은',
#   '적당한',
#   '아이디어',
#   '독자',
#   '우리',
#   '더',
#   '집중하고',
#   '단순',
#   '히',
#   '전달',
#   '하게',
#   '만들고',
#   '얼마',
#   '나',
#   '특정',
#   '심리학자',
#   '이용할수',
#   '있는',
#   '증거',
#   '이해',
#   '하고',
#   '설명',
#   '하기위해',
#   '시도',
#   '했다'],
#  ['이러한', '편견', '들로', '우리', '정확', '하지', '않은', '생각', '으로', '삶을', '살아', '간다'],
#  ['지식', '성질을', '이해', '하는', '것은', '우리', '잘못', '생각', '바로', '있다'],
#  ['메일', '동영상', '과', '같은', '것들', '저장', '될', '있다'],
#  ['너가', '원하는', '언제든지', '과거', '사건', '으로', '돌아', '갈', '있다'],
#  ['책', '읽는', '것은', '도로', '에서', '운전', '하는', '것과', '닮았다'],
#  ['목동들', '차', '문화', '체계', '따르며', '그들', '우유', '와', '함께', '마신다'],
#  ['아이', '에게', '주목하고', '있고', '생각', '하고', '있다는', '것을', '확신', '시키게', '해준다'],
#  ['차가', '땡기지만', '차를', '끓일', '시간', '없나'],
#  ['인간', '생존', '감정', '역할'],
#  ['포식자', '수가', '증가', '하는', '이유'],
#  ['혜성',
#   '발견',
#   '이전',
#   '여성들',
#   '천문학자',
#   '두명',
#   '이었기',
#   '때문',
#   '그녀',
#   '혜성',
#   '발견은',
#   '그녀',
#   '에게',
#   '세계적',
#   '인기',
#   '주었다'],
#  ['날마다', '하는', '학교', '일은', '지루', '하고', '반복적', '이어서', '동기부여', '될', '필요가', '있다'],
#  ['관계', '위반은', '인간', '과', '신의', '분노', '가져왔다'],
#  ['인격',
#   '자신',
#   '이익추구',
#   '지연스러운',
#   '특성',
#   '으로',
#   '인정',
#   '하지만',
#   '인간',
#   '주저함에대한',
#   '그것',
#   '믿음',
#   '둔다',
#   '하지만',
#   '협력',
#   '하는',
#   '따뜻',
#   '본능',
#   '둔다'],
#  ['처음', '너의', '집에', '방문', '했을때', '너의', '아버지', '대해', '좋은느낌을', '가졌다'],
#  ['의사', '윌리엄은', '글을', '쓰려고', '노력', '했다'],
#  ['후보자', '즐거운', '사람', '으로', '보이는지는', '중요', '요소', '임'],
#  ['중요', '것은', '개성이', '아니라', '능력', '이다'],
#  ['그자체', '충분', '한것'],
#  ['행운', '사람', '에게', '가장', '귀중', '자산이다'],
#  ['사람들', '익숙', '자극', '쪽으로', '선호', '발전', '시킨다'],
#  ['볼레',
#   '로는',
#   '그',
#   '선물을',
#   '받고',
#   '얼마',
#   '나',
#   '많은',
#   '노예',
#   '들이',
#   '페루',
#   '있나요',
#   '라고',
#   '물어보았다'],
#  ['하지만',
#   '그',
#   '증거',
#   '그들',
#   '피부상태',
#   '객관적',
#   '이지',
#   '못한',
#   '단순',
#   '예들로',
#   '단지',
#   '개인적',
#   '의견',
#   '기초',
#   '한다는',
#   '뜻이다'],
#  ['연구', '따르면', '그', '종은', '주로', '나무', '사는', '것처럼', '보여진다고', '생각', '되었다'],
#  ['극단적',
#   '으로',
#   '긴팔과',
#   '짧은',
#   '뒷다리는',
#   '현대',
#   '오랑우탄처럼',
#   '매달리는데',
#   '시간',
#   '썼다는',
#   '것을',
#   '암시',
#   '한다'],
#  ['복사되는', '것은', '복사되는', '사실자체', '보다도', '중요', '있다'],
#  ['비록', '이것', '사치스러워보여도', '사실', '가난한', '사람들', '이것', '허기를', '달래는데', '쓴다'],
#  ['관점', '따르면', '풍부', '종이', '더', '많으면', '단일', '종이', '덜', '중요', '해진다'],
#  ['하지만',
#   '갈수록',
#   '더',
#   '많은',
#   '농지',
#   '들이',
#   '개발국가',
#   '갈망',
#   '하는',
#   '인구',
#   '들에게',
#   '희생',
#   '되면서',
#   '차의',
#   '미래',
#   '역할',
#   '대해',
#   '의문',
#   '제기',
#   '되었다'],
#  ['미국',
#   '증가',
#   '하는',
#   '거식증',
#   '소년',
#   '작은',
#   '몸의',
#   '특징',
#   '보다',
#   '근육질',
#   '남자',
#   '체격',
#   '성장',
#   '할수록',
#   '강조하는것',
#   '관련',
#   '있다'],
#  ['일련의',
#   '자극',
#   '들에게',
#   '노출',
#   '시간',
#   '길이',
#   '측정',
#   '하기위해',
#   '사람들',
#   '에게',
#   '요구',
#   '하는것은',
#   '새로운',
#   '자극',
#   '반복적',
#   '이거나',
#   '일상적인',
#   '것에',
#   '비해',
#   '더이상',
#   '길지',
#   '않다는',
#   '것을',
#   '보여준다'],
#  ['성공', '과', '성취', '같은', '것이', '아니지만', '우리', '오해한다'],
#  ['적절', '농업', '시스템', '농부', '가뭄을', '극복', '하도록', '도울', '있다'],
#  ['너는',
#   '누군가',
#   '행동',
#   '원인',
#   '찾을때',
#   '내적',
#   '기질',
#   '우선시',
#   '하는지',
#   '궁금',
#   '하게',
#   '될',
#   '것이다'],
#  ['그것', '건기를', '요구', '하기에', '우림', '에서는', '찾을', '없다'],
#  ['이로인해', '우리', '뇌는', '함정', '될', '수도', '있고', '우리', '속임에', '공범', '된다'],
#  ['주거지', '보호', '생태계', '파괴', '문제들', '막는다'],
#  ['연구센터', '발명', '가들은', '너를', '차를', '마셨을때', '처럼', '활기를', '띠게', '만들것이라고', '말한다'],
#  ['취미활동해서', '경험', '넓혀라'],
#  ['또',
#   '다른',
#   '방어',
#   '로는',
#   '묻기가',
#   '있다',
#   '그것',
#   '설치류',
#   '들이',
#   '그들',
#   '발과',
#   '머리',
#   '사용',
#   '싫어',
#   '하는',
#   '자극',
#   '쪽으로',
#   '먼지를',
#   '파내는',
#   '것이다'],
#  ['다른',
#   '행동',
#   '선택',
#   '들은',
#   '큰소음내기',
#   '후퇴하기',
#   '둥글게',
#   '말기',
#   '지하도와',
#   '같은',
#   '육식동물에게서',
#   '자유',
#   '로운',
#   '지역',
#   '에서',
#   '살기',
#   '집단',
#   '에서의',
#   '수적인',
#   '안전',
#   '함에',
#   '의지',
#   '하기가',
#   '있다'],
#  ['내가',
#   '모든',
#   '사람들',
#   '많은양의',
#   '정보',
#   '저장하고',
#   '제어하고',
#   '기억',
#   '하도록',
#   '만들어',
#   '진',
#   '뇌를',
#   '가진',
#   '잠재적',
#   '천재',
#   '라는',
#   '것을',
#   '너에게',
#   '증명',
#   '하겠다'],
#  ['상점', '분류', '대로', '정리', '되어있고', '너는', '여러', '차례', '쇼핑', '했다'],
#  ['반복', '그리고', '범주화', '기억', '하는', '열쇠'],
#  ['서투른', '노동자', '그의', '도구', '탓한다'],
#  ['바닷가재', '항상', '귀한', '것은', '아니다'],
#  ['사치품', '들과', '마찬가지로', '비용', '즐거움과', '연결', '된다'],
#  ['상승기류', '태양', '의해', '열을', '받은', '땅에', '서', '시작', '할지도', '모른다'],
#  ['구체적', '글은', '실력있는', '작가', '나타', '내고', '줄거리', '대한', '분명', '이해', '얻도록', '도움'],
#  ['연구',
#   '일부',
#   '캔음식',
#   '암',
#   '심장병',
#   '비만의',
#   '높은',
#   '위험',
#   '연관',
#   '되있다는',
#   '것을',
#   '보여준다'],
#  ['1900년대', '초반', '암환자들은', '오랜기간', '생존', '없었다'],
#  ['우리', '좋은', '잠', '그리고', '따뜻', '음식', '얻는다'],
#  ['대부분', '사람들', '아는대로', '일본', '문자는', '그림', '처럼', '보이고', '표의문자', '라고', '불린다'],
#  ['환경', '문제', '다루는', '최고', '방법', '예방', '이다'],
#  ['이스터는',
#   '거실',
#   '지나',
#   '쳐',
#   '그녀',
#   '침대',
#   '기쁜마음으로',
#   '달려',
#   '여기로',
#   '와보세요',
#   '엄마',
#   '라고',
#   '소리',
#   '쳤다'],
#  ['그리고', '노예', '들을', '얼마', '나', '팔수', '있는지', '그가', '알길', '원했다'],
#  ['비록',
#   '영양학자들이',
#   '이물질에',
#   '대해',
#   '저명한',
#   '과학자',
#   '그레이',
#   '터부처럼',
#   '기록',
#   '하더라도',
#   '포화지방',
#   '소비',
#   '더',
#   '추천',
#   '하는',
#   '것이',
#   '누구',
#   '나',
#   '심장병',
#   '고위험이',
#   '되어',
#   '죽음을',
#   '유발',
#   '한다는',
#   '생각',
#   '하게',
#   '되는',
#   '증거',
#   '아니라고',
#   '관찰',
#   '한다'],
#  ['인도인', '들의', '식사', '그의', '지역', '종교', '사회', '카스트제도에', '의존', '한다'],
#  ['성취', '도달', '하거나', '얻어야', '하는', '목표', '와', '같은', '것이다'],
#  ['경제',
#   '크게',
#   '성장',
#   '했음에도',
#   '불구하고',
#   '자동차화',
#   '비율',
#   '유지',
#   '됬고',
#   '탄소',
#   '방출',
#   '량은',
#   '감소',
#   '했다'],
#  ['15분', '넘는', '시간동안', '그들', '박수', '쳤다'],
#  ['여러',
#   '요소',
#   '들이',
#   '시간',
#   '지남에',
#   '따라',
#   '변화',
#   '지도',
#   '모르지만',
#   '사람들',
#   '게시',
#   '글의',
#   '내용',
#   '그',
#   '상태',
#   '그대로',
#   '보존',
#   '된다'],
#  ['책의', '종류', '와', '다른', '속도', '책을', '읽는', '것은', '독서', '에서', '문제', '생긴다'],
#  ['날씨', '정보', '모으는', '시스템', '농부들', '농작물', '관리', '하는', '것을', '돕는다'],
#  ['많은', '아이들', '그', '순간', '의미', '있고', '흥미', '롭게', '느낌'],
#  ['둘중', '한사람', '10', '달라', '받음'],
#  ['9살', '그는', '연주', '장에서', '첫번째', '연주', '했다'],
#  ['개발도상국',
#   '에서',
#   '대다수',
#   '경쟁',
#   '없는',
#   '농업인',
#   '들이',
#   '경쟁',
#   '못하는',
#   '동안',
#   '소수',
#   '농업인',
#   '들은',
#   '기술적',
#   '이득',
#   '보고있다'],
#  ['시즌오프에', '상품', '이나', '서비스', '제공', '받는게', '이득', '이다'],
#  ['그것', '우리', '생존', '과', '혁명', '역사', '도움을', '줬다'],
#  ['그', '결과', '그들', '위험', '줄이기', '위한', '전략', '사용', '하도록', '동기부여', '받는다'],
#  ['종종', '사람', '얼굴', '기억', '해도', '이름', '기억', '못한다'],
#  ['인격', '무지', '민감', '폭정을', '싫어하고', '발전', '항상', '열려', '있다'],
#  ['내가', '집에', '갔던', '첫', '날', '그의', '손으로', '지은', '경사로', '준비', '되어', '있었다'],
#  ['범죄', '통제', '어렵고', '논란이', '많다'],
#  ['52', '투표자', '들이', '유럽연합', '떠나자고', '선택', '했다'],
#  ['투표자', '들의', '52', '유럽연합', '떠날', '것을', '원했다'],
#  ['나비',
#   '결함은',
#   '전체',
#   '영향',
#   '주는',
#   '위험',
#   '과',
#   '그들',
#   '효과적',
#   '경영사이에서의',
#   '넓은',
#   '차이',
#   '다룬다'],
#  ['다른', '것들', '에대해', '관대', '한것'],
#  ['상승', '땅보다', '해에', '의해서', '열이', '더', '올라', '시작', '것이다'],
#  ['공기',
#   '땅과',
#   '반대방향',
#   '으로',
#   '올라서',
#   '더',
#   '가볍고',
#   '더',
#   '위로',
#   '뜰',
#   '것이다',
#   '그',
#   '주변',
#   '공기',
#   '보다'],
#  ['30년동안', '과학적', '합의는', '뒤집어', '졌고', '포화지방', '더이상', '해롭지', '해롭지', '않다'],
#  ['스피드킹', '유일', '성공작품', '이라', '판명되더라도', '이것', '흥미', '로운', '전기', '자동차', '이다'],
#  ['수평적',
#   '형태',
#   '일반적',
#   '이고',
#   '두루마리',
#   '쾌',
#   '길기',
#   '때문',
#   '필경사는',
#   '전형적',
#   '으로',
#   '전체길이',
#   '단독줄로',
#   '그어서',
#   '쓰는것을',
#   '금지',
#   '했고',
#   '대신',
#   '합리적인',
#   '길이',
#   '세로줄로',
#   '표시',
#   '했다'],
#  ['성공', '해도', '그들', '항상', '성취', '느끼지는', '않는다'],
#  ['이러한', '사람들', '다른', '사란들에게', '자주', '이야기', '하며', '그들', '에게', '영향', '끼친다'],
#  ['그녀', '그를', '격려', '하면서', '웃고', '있었다'],
#  ['그것', '의미', '있는', '수는', '아니다'],
#  ['완벽', '보존', '가능', '때', '시간', '중단', '되어', '있다'],
#  ['손가락', '두드림은', '영원히', '존재', '했을', '수도', '있을', '문서를', '무의', '상태', '보낼', '있다'],
#  ['티크', '금색', '과', '갈색', '띄는', '붉은색', '가지고', '있어서', '매력적', '이다'],
#  ['영국',
#   '심리학자',
#   '자신',
#   '운이',
#   '좋다고',
#   '생각',
#   '하는',
#   '사람들',
#   '과',
#   '그렇지',
#   '않은',
#   '사람들',
#   '실험'],
#  ['비디오', '시작', '후', '식당', '밖에', '사람들', '줄을', '섬'],
#  ['농구', '경기', '승패의', '기준', '골이', '어떻게', '들어갔냐가', '아니다'],
#  ['왜',
#   '영화',
#   '순수한',
#   '행동',
#   '실제',
#   '생활',
#   '에서는',
#   '표현',
#   '불분명한',
#   '사람들',
#   '에게',
#   '부자연',
#   '스러워',
#   '보이지',
#   '않는가'],
#  ['옥수수', '같은', '중요', '농작물', '들이', '충분', '생산', '안됨'],
#  ['그', '문제들', '발생', '막는것이', '가장', '좋은', '방법', '이다'],
#  ['회복', '생태계', '손상', '되돌려', '놓는다'],
#  ['쓰레기', '증가', '질병', '원인', '됐다'],
#  ['그는', '샴페인병에', '음식', '저장', '하는', '실험', '했다'],
#  ['인간', '수천년동안', '모래', '또는', '벽에', '그림', '그려서', '생각', '과', '경험', '전달', '했다'],
#  ['어떤',
#   '것이',
#   '안좋게',
#   '갈때',
#   '사람들',
#   '계속',
#   '진행',
#   '하도록',
#   '유지',
#   '시킨',
#   '것은',
#   '그들',
#   '열정',
#   '이다'],
#  ['재산', '사이트', '방문객', '에게', '새로', '나온', '부동산', '대해', '말한다'],
#  ['인격', '의미', '하는것'],
#  ['그들',
#   '환심을',
#   '샀던',
#   '후보자',
#   '들은',
#   '성공',
#   '위해',
#   '매혹',
#   '자리',
#   '제공',
#   '받을',
#   '가능성이',
#   '있다'],
#  ['많은', '자격', '증이', '더', '좋은', '기회', '가져온다'],
#  ['예술',
#   '가들은',
#   '그들',
#   '자신',
#   '가쁨을',
#   '위해서',
#   '창조',
#   '뿐만',
#   '아니라',
#   '그들',
#   '작품',
#   '들이',
#   '알려지고',
#   '인정',
#   '받기를',
#   '원한다'],
#  ['실험',
#   '에서',
#   '각각',
#   '표의문자',
#   '노출',
#   '지속',
#   '의도',
#   '적으로',
#   '10',
#   '00분의',
#   '3초만큼',
#   '짧게',
#   '유지',
#   '되었다'],
#  ['또',
#   '다른',
#   '방어',
#   '방어적',
#   '으로',
#   '묻는',
#   '것이다',
#   '설치류',
#   '발과',
#   '머리',
#   '사용',
#   '먼지를',
#   '털어',
#   '혐오',
#   '하는',
#   '자극',
#   '향해',
#   '사용',
#   '것이다'],
#  ['곧',
#   '시몬',
#   '볼레',
#   '라는',
#   '자유',
#   '이끄는',
#   '세력의',
#   '수장인',
#   '장군은',
#   '새로운',
#   '나라',
#   '첫번째',
#   '구성',
#   '으로',
#   '쓰여진',
#   '회의',
#   '가졌다'],
#  ['피드백', '너의', '신체', '부터', '얻게', '된다'],
#  ['너는', '읽기를', '배웠을', '때', '글을', '읽는', '법에', '대해', '배웠을지도', '모른다'],
#  ['다른', '것은', '16초간', '지속', '됨'],
#  ['그녀', '내용', '설명', '계속', '했다'],
#  ['그들',
#   '구체적',
#   '목표',
#   '초점',
#   '두지',
#   '다른',
#   '것은',
#   '지나',
#   '친',
#   '다는',
#   '것을',
#   '알아',
#   '차리지',
#   '못한다'],
#  ['유목민들의', '식단', '에는', '채소', '부족', '한데', '차가', '그', '역할', '보완한다'],
#  ['그들',
#   '크고',
#   '둥근',
#   '노란',
#   '눈은',
#   '우리',
#   '어둠',
#   '속에서',
#   '그것',
#   '알아',
#   '차리는',
#   '요소',
#   '중',
#   '하나이다'],
#  ['늘어',
#   '나는',
#   '여가',
#   '수업',
#   '과',
#   '지역',
#   '발전',
#   '기회',
#   '여러',
#   '나라',
#   '산림',
#   '경관에',
#   '비슷',
#   '변화',
#   '가지고',
#   '옴'],
#  ['국민성', '각기', '다른', '어려움', '이다'],
#  ['바다뱀', '노란배는', '포식자들', '아무것도', '시도', '하지', '못하게', '말한다'],
#  ['다른', '문화권', '들의', '감정', '표현', '차이'],
#  ['당신', '어린시절', '돌아', '간다고생각해봐라'],
#  ['진화', '종류', '따른', '생존', '전략', '영향'],
#  ['그녀', '1977년', '스탠포드', '대학', '에서', '학위를', '가지고', '졸업'],
#  ['다른', '같은', '물건', '보다', '베블런', '상품', '더', '질이', '좋은건', '아닐', '것이다'],
#  ['과장', '하는', '작가'],
#  ['사실', '알고있다면', '사용', '해라'],
#  ['침팬지', '0에서', '9까지', '숙달', '하는데까지', '몇년', '걸렸다'],
#  ['우리',
#   '새로운',
#   '기술들',
#   '인간적',
#   '이고',
#   '사회적',
#   '문제들',
#   '과',
#   '이익',
#   '야기',
#   '것이라는',
#   '것을',
#   '정말',
#   '안다'],
#  ['그럼에도',
#   '불구하고',
#   '참가',
#   '자들이',
#   '이전',
#   '노출',
#   '되었던',
#   '하나',
#   '노출',
#   '되었던',
#   '없는',
#   '다른',
#   '하나',
#   '문자',
#   '두세트를',
#   '보여졌을',
#   '때',
#   '참가',
#   '자들은',
#   '전자',
#   '대한',
#   '더',
#   '큰',
#   '선호',
#   '기록',
#   '했다'],
#  ['그는',
#   '인종',
#   '차별에',
#   '대해서',
#   '인식',
#   '변화',
#   '불가능',
#   '인식',
#   '하고',
#   '흑인',
#   '시인',
#   '처럼',
#   '글을',
#   '써왔다'],
#  ['17세기에서',
#   '18세기에는',
#   '보여지지않았다',
#   '그리고',
#   '그때',
#   '여성',
#   '몸은',
#   '포동포동한',
#   '비만을',
#   '우상화',
#   '했다'],
#  ['평화', '나의', '두려움을', '없앴다'],
#  ['직원',
#   '그들',
#   '아이',
#   '돌봄',
#   '프로그램',
#   '위해',
#   '돈의',
#   '일부',
#   '사용하고',
#   '자',
#   '하면',
#   '그',
#   '직원',
#   '돈으로',
#   '부터',
#   '사용',
#   '될',
#   '것이다'],
#  ['그는', '오케스트라', '와', '한동안', '함께', '연주', '했다'],
#  ['왕이', '말했다'],
#  ['아나운서는', '그', '슛이', '예쁘지', '않다고', '하며', '그녀', '말은', '옳을', '것이다'],
#  ['필사본', '희귀', '하고', '재생산', '못한다'],
#  ['움직',
#   '이지',
#   '않는것',
#   '과',
#   '같은',
#   '죽은척',
#   '하기는',
#   '공격',
#   '막을',
#   '있다',
#   '그러나',
#   '움직',
#   '이지',
#   '않기',
#   '에서',
#   '근육',
#   '싸움',
#   '또는',
#   '도망',
#   '에서',
#   '사용',
#   '되기',
#   '위해',
#   '수축되고',
#   '태세를',
#   '갖추는',
#   '반면에',
#   '긴장',
#   '부동화',
#   '죽은척',
#   '하기',
#   '에서',
#   '근육',
#   '진정',
#   '된다'],
#  ['안전', '구매', '소비자들', '간절하게', '추구', '하는것'],
#  ['지능',
#   '사물들',
#   '있는',
#   '그대로',
#   '여기고',
#   '그것들',
#   '조작을',
#   '가능',
#   '하게',
#   '하는',
#   '것의',
#   '목적',
#   '가지는',
#   '조합',
#   '만들면서',
#   '생체학적',
#   '생존',
#   '위한',
#   '것으로',
#   '여겨짐',
#   '지능',
#   '사물',
#   '있는',
#   '그대로',
#   '받아들이고',
#   '다양',
#   '방식',
#   '으로',
#   '사용',
#   '지능',
#   '생체학적',
#   '생존',
#   '가능',
#   '하게'],
#  ['이성',
#   '기능',
#   '정신',
#   '이나',
#   '정신적',
#   '존재',
#   '만큼',
#   '물리적',
#   '것을',
#   '발전',
#   '시키는',
#   '것은',
#   '아니다'],
#  ['침팬지', '숫자', '능력', '한계'],
#  ['당신', '개인적', '관심사', '말하는', '것이', '더', '좋다'],
#  ['영국', '에서', '역사적', '국민투표가', '일어', '났다'],
#  ['미래', '위한', '합리적인', '각본', '생각', '해내다'],
#  ['감정', '그대로', '받아들인다'],
#  ['부동산', '사이트', '부동산', '정보', '고객', '에게', '알려준다'],
#  ['반대',
#   '만약',
#   '너가',
#   '땅의',
#   '모든',
#   '정각',
#   '미터마다',
#   '감지',
#   '기를',
#   '갖고있다면',
#   '몇몇',
#   '감지',
#   '기의',
#   '부정확',
#   '데이터',
#   '문제',
#   '일으키지',
#   '않는다'],
#  ['몇몇', '성공', '대해', '의문', '있다'],
#  ['너가', '로봇', '이라면', '결정', '내리기', '위해', '하루', '종일', '시도', '했을', '것이다'],
#  ['왕은', '그에게', '자신', '무엇', '있냐고', '물었다'],
#  ['완벽', '완벽', '지우고', '완전', '넣는다면', '가능', '하다'],
#  ['개개인',
#   '직접',
#   '날씨',
#   '측정',
#   '하기',
#   '보다는',
#   '정확',
#   '지역',
#   '정보',
#   '각',
# ...
#  ['발전', '아직', '적응', '하지', '못했다'],
#  ['지난', '선거', '보다', '참여', '자', '수가', '더', '높았다'],
#  ['흥미', '있고', '재미', '있다'],
#  ['두번째', '소음', '불쾌', '하게', '두배', '더', '길게', '지속', '됬다'],
#  ['두', '소음', '모두', '불쾌', '했지만', '두', '번째', '첫', '번째', '보다', '낫게', '느껴졌다'],
#  ['도심에서', '속도', '내는', '것은', '위험', '하기', '때문', '배우지', '않음'],
#  ['사람들', '주어진', '환경', '따라', '생계를', '살아', '간다'],
#  ['가상현실', '노출', '치료법', '치료', '효과적', '이게', '보여져왔다'],
#  ['각각', '사건', '들은', '학생들', '다양', '관점', '으로', '부터', '검사', '하도록한다'],
#  ['영국', '인의', '대다수', '보수적', '으로', '옷을', '입는다'],
#  ['현재에', '집중', '하라'],
#  ['블랙홀', '검은색', '이고', '어떤', '것도', '방출', '하지', '않는다'],
#  ['블랙홀', '에서', '뭐해'],
#  ['사회',
#   '에서',
#   '이성',
#   '예측',
#   '위해서',
#   '필요',
#   '한데',
#   '예측',
#   '가끔',
#   '신체적',
#   '요소',
#   '필요',
#   '하기도한다'],
#  ['폭풍은', '따뜻', '공기', '상승', '기류', '구성', '된다'],
#  ['너는',
#   '테이블',
#   '에서',
#   '재료',
#   '버리고',
#   '그',
#   '아이템',
#   '일치하는',
#   '그룹',
#   '으로',
#   '분리하기',
#   '시작',
#   '하라'],
#  ['지속적', '상호작용', '시대', '살아', '가고', '있지만', '우리', '이전', '보다', '외롭다'],
#  ['그녀', '그녀', '질병', '치료', '하기', '위한', '돈이', '없었다'],
#  ['가이드', '나이가', '많은', '남자', '였다'],
#  ['놀때', '느꼇던', '감정', '찾으면', '더', '행복', '해짐'],
#  ['뇌우는', '전세계적', '으로', '흔하다'],
#  ['어떤', '것을', '말하지', '말아야', '때를', '배우는', '것은', '중요', '하다'],
#  ['내가',
#   '무슨말을',
#   '하고싶은지',
#   '왜',
#   '말하고싶은지',
#   '스스로',
#   '물어보고',
#   '듣는사람에게',
#   '도움되지',
#   '않는',
#   '정보',
#   '라면',
#   '말하지',
#   '말아야',
#   '한다'],
#  ['대화', '때', '계획', '하는게', '중요', '한데', '많이', '말을', '해봐라'],
#  ['폭력범죄는', '떨어지고있지만', '전반적인', '범죄율', '높다'],
#  ['전문', '적인', '기술', '적어도', '1만', '시간', '연습', '해야한다'],
#  ['그것',
#   '또한',
#   '영국',
#   '에서',
#   '비옥한',
#   '농토의',
#   '일부분',
#   '으로',
#   '축복받았다',
#   '그리고',
#   '흐름',
#   '영향',
#   '덕분에',
#   '놀랄만큼',
#   '따뜻',
#   '기온',
#   '으로'],
#  ['스위치를', '켜기', '전에', '나는', '모든', '것이', '고장', '났다는것을', '알게', '됐다'],
#  ['아름', '다운', '색으로', '뛰어', '난', '것이', '하늘', '위에', '걸려있다'],
#  ['우리', '아이들', '만약', '그들', '선조들의', '문화', '되돌아간다면', '무섭다고', '말한다'],
#  ['그는', '3천명', '가까이', '사람', '된다고', '말했다'],
#  ['캐릭터들', '좋은', '뭔가가가', '되는데', '왜냐하면', '대화', '하기에', '좋은', '핑계를', '줘서'],
#  ['이러한', '자부심', '행동', '선천적이다'],
#  ['그는', '오전', '10', '시에', '대학', '병원에', '도착', '했다'],
#  ['그는',
#   '수업',
#   '참여',
#   '하기',
#   '보단',
#   '호박파이',
#   '존재',
#   '대해',
#   '의문',
#   '가지게',
#   '될',
#   '지도',
#   '모른다'],
#  ['목적',
#   '지닌',
#   '스키',
#   '리조트',
#   '또는',
#   '스키',
#   '공장',
#   '들은',
#   '1950년대',
#   '후반에',
#   '지역발전',
#   '위해',
#   '지어짐'],
#  ['자본가', '방식', '소작농', '음식문제', '일으킨다'],
#  ['사회', '과학자들은', '사람들', '차이점', '고려', '해야하지만', '방법', '찾지', '못했다'],
#  ['우리', '혐호의', '얼굴', '보며', '곰팡이', '핀', '음식', '피할', '있다'],
#  ['21살때', '건강', '악화로', '꿈을', '포기', '했고', '23살때', '글을', '쓰기', '시작', '했다'],
#  ['징기스칸', '생각', '보다', '잔인', '사람들', '싫어', '수도', '있다'],
#  ['결국', '침팬지', '빈번', '한오류를', '냈다'],
#  ['많은', '것이', '있는', '식료품점', '상상', '해봐'],
#  ['높은', '가격', '지불', '해야하는', '의지', '더', '좋은', '퀄리티보다', '상대방의', '부를', '만들기때문'],
#  ['하지만', '고고학자', '도굴꾼과', '함께', '일을', '하지', '않는다'],
#  ['내', '이름', '불릴', '때까지', '나는', '대기', '장소', '있었다'],
#  ['아프리카', '인들은', '미국인', '들은', '위한', '고구마', '파이', '내놓고는', '한다'],
#  ['소녀', '두', '개의', '사과', '쥐고', '있었다'],
#  ['그는', '왕에게', '자신', '에게', '금을', '빚지고', '있다고', '말했다'],
#  ['도움을', '주면', '감사', '하다고', '말하고', '있음'],
#  ['산업', '농부들', '넓은', '농업', '정보', '얻기', '위해', '인터넷', '사용', '한다'],
#  ['농업',
#   '발달',
#   '분균형과',
#   '자본가',
#   '들의',
#   '행포는',
#   '개발도상국',
#   '농업인',
#   '들을',
#   '중요',
#   '음식',
#   '으로부터',
#   '괴롭힌다'],
#  ['상상력', '풍부', '함의', '장점', '행복', '흥분'],
#  ['다른', '종을', '공격', '하는', '동물들'],
#  ['쿠키', '개인들', '에게', '매우', '선호', '된다'],
#  ['그녀', '내가', '옷을', '벗기전에', '이미', '잠들었다'],
#  ['그들', '입는', '것은', '사회', '대표', '적인', '것이', '못된다'],
#  ['미래발전', '대해', '고안하고', '쉽고', '가능', '하다'],
#  ['유명',
#   '인은',
#   '실수',
#   '해도',
#   '훌륭한',
#   '사람',
#   '이기',
#   '때문',
#   '실수',
#   '해도',
#   '괜찮다고',
#   '느껴질',
#   '수도',
#   '있다',
#   '안',
#   '유명',
#   '인은',
#   '실수',
#   '하면',
#   '안되나요'],
#  ['그녀', '혼자', '방사능을', '연구', '했고', '그는', '혼자', '운동법칙', '발견', '했다'],
#  ['그는', '최근', '자동차', '쇼에', '방문', '하여', '큰', '인상을', '받고', '투자', '결정', '지었다'],
#  ['그리고', '딸은', '그가', '먹은', '사과', '중', '하나를', '엄마', '에게', '건냈다'],
#  ['환자들은', '이를', '통해', '그들', '불안감', '과', '공포', '증을', '극복', '하는', '것을', '배운다'],
#  ['기온', '올라서', '좋음'],
#  ['소녀', '들이', '공부', '하는', '동안', '앉아있어야했다'],
#  ['소수', '상류층', '과', '전문', '적인', '중상류층은', '지난', '50년정도의', '스타일', '입는다'],
#  ['많은', '남자', '들은', '상위계층에', '있는것을', '알', '있는', '여전히', '맞춤', '정장을', '만든다'],
#  ['영국', '유럽연합', '구성원', '으로', '남을지', '떠날지에대해', '투표', '했다'],
#  ['뱀이', '편견', '없이', '보면', '예쁘고', '착한', '구성원', '이라', '있다'],
#  ['행복', '해하는', '사람', '에게', '이건', '괜찮은'],
#  ['웹브라우저', '고객', '정보', '쿠키', '저장', '서버가', '기억', '한다'],
#  ['전통적',
#   '으로',
#   '대부분',
#   '생태학자글은',
#   '추정',
#   '한다',
#   '사회',
#   '안정성은',
#   '환경',
#   '침해를',
#   '버틸수',
#   '있는',
#   '사회',
#   '능력',
#   '이므로',
#   '사회',
#   '복잡성',
#   '결과',
#   '이다'],
#  ['독서', '충돌', '막기', '위해', '책의', '종류', '고려', '필요가', '있다'],
#  ['올빼미', '간상체', '색상', '추상체보다', '어둠', '속에서', '더', '많은', '것을', '볼', '있게함'],
#  ['근면하게', '개인적', '으로', '공부', '하게', '훈련', '받은', '아이들', '시험', '성적', '잘', '받음'],
#  ['웃고', '눈맞춤', '하는', '것도', '노력', '된다'],
#  ['어린아이는',
#   '종종',
#   '자발적',
#   '10',
#   '까지',
#   '셀',
#   '있고',
#   '빠르게',
#   '더',
#   '다양',
#   '숫자',
#   '나아',
#   '간다'],
#  ['수백', '만명의', '사람들', '재투표를', '요청', '했다'],
#  ['유럽연합', '브렉시트'],
#  ['가을', '학기에', '대학', '원', '시작'],
#  ['보수적', '친구', '에게는', '단어', '좋은', '의미'],
#  ['많은', '종들', '공원', '과', '보호지역', '두는'],
#  ['문화변화',
#   '좋은지',
#   '나쁜지',
#   '공적투표를',
#   '하게',
#   '될때',
#   '하나의',
#   '대답',
#   '뚜렷하게',
#   '앞서고',
#   '다른',
#   '대답',
#   '떨어지는',
#   '것을',
#   '볼',
#   '있다'],
#  ['초기에',
#   '파피루스와',
#   '양피지는',
#   '두루마리',
#   '채로',
#   '유지',
#   '됐다',
#   '수직',
#   '적이거나',
#   '수평적',
#   '으로',
#   '말려있지',
#   '않고',
#   '필기문자',
#   '방향',
#   '으로',
#   '의지',
#   '했다'],
#  ['그는', '그가', '살아', '가는데', '대수학', '도움이', '되지', '않아', '배우지', '않는다'],
#  ['가장', '친한', '친구', '희귀', '병', '진단을', '받았다'],
#  ['그들', '실생활에서난', '영화', '에서나', '면밀', '히', '관찰', '하지', '않음'],
#  ['그녀',
#   '그녀',
#   '무릎',
#   '천천히',
#   '풀어주었고',
#   '그녀',
#   '머리',
#   '똑바로',
#   '했다',
#   '더',
#   '잘',
#   '듣기',
#   '위해서'],
#  ['노령화', '사회', '새로운', '시장', '등장'],
#  ['불이행시', '새로운', '법이', '나올', '것이다'],
#  ['많은',
#   '도시',
#   '들은',
#   '적은',
#   '비용',
#   '유출되는',
#   '하수',
#   '다루고',
#   '거를',
#   '있는',
#   '인공적인',
#   '습지',
#   '찾아왔어요'],
#  ['교통', '심한', '추수감사절', '후', '고속도로', '블랙', '아이스', '있음'],
#  ['다른',
#   '분야',
#   '있는',
#   '과학자',
#   '중에',
#   '그가',
#   '찾은',
#   '것과',
#   '생각',
#   '들을',
#   '통해',
#   '자리',
#   '마련',
#   '해주는',
#   '사람',
#   '있다'],
#  ['그는', '고양이', '그리는', '것을', '좋아', '했다'],
#  ['건축물',
#   '영화',
#   '전반적인',
#   '분위기에',
#   '기여',
#   '하면서',
#   '줄거리',
#   '와',
#   '등장인물',
#   '정보',
#   '전달',
#   '한다'],
#  ['영화',
#   '제작자는',
#   '영화',
#   '에서',
#   '등장인물',
#   '삶이나',
#   '동시대의',
#   '본질',
#   '다양',
#   '부분',
#   '은유',
#   '적이기',
#   '말하기',
#   '위해',
#   '카메라',
#   '사용',
#   '있다'],
#  ['고전음악', '과', '코미디', '결합', '스타일', '공연'],
#  ['행성', '전체', '따뜻', '해지고있다'],
#  ['네명은', '광고', '업에서', '오랫동안', '일했다'],
#  ['연구', '하는', '46억년', '이상', '전에', '지구', '변해왔어'],
#  ['수십년',
#   '동안',
#   '고곡학자들은',
#   '최초',
#   '원주민들',
#   '지구',
#   '온난화',
#   '시기',
#   '아시아',
#   '와',
#   '남아메리카',
#   '연결',
#   '시키는',
#   '아주',
#   '넓고',
#   '긴',
#   '땅인',
#   '노아의',
#   '방주를',
#   '타고',
#   '아메리카',
#   '거주',
#   '하게',
#   '되었다'],
#  ['장남감', '로켓', '우주시대', '초기', '인기', '있다'],
#  ['이성', '기능', '적인게', '아니다', '그러나', '정신', '력처럼', '만히', '더', '신체적', '것은', '아니다'],
#  ['이러한',
#   '일들',
#   '우리',
#   '쉽게',
#   '상상',
#   '있을',
#   '뿐이지',
#   '자주',
#   '일어',
#   '나지',
#   '않는',
#   '일들',
#   '이다'],
#  ['앤은',
#   '컴퓨터',
#   '사용',
#   '하는',
#   '독자들',
#   '과',
#   '종이',
#   '사용',
#   '하는',
#   '독자들',
#   '비교',
#   '하는',
#   '연구',
#   '했다'],
#  ['경기', '하고', '있는', '유격수', '관해', '아는', '것은', '야구', '영역', '구체적', '지식', '이다'],
#  ['두번째', '8초', '처음', '만큼', '크지', '않았다'],
#  ['학생',
#   '표절',
#   '자신',
#   '에게',
#   '더',
#   '좋다고',
#   '항의',
#   '하더라도',
#   '우리',
#   '그',
#   '점을',
#   '즉시',
#   '인정',
#   '하지',
#   '않는다'],
#  ['1940년', '나치가', '덴마크', '침공했을떄', '미국', '으로', '도망', '침'],
#  ['환경', '보존', '과', '환경', '회복', '위한', '기술들', '있다'],
#  ['과일을',
#   '보존',
#   '하는',
#   '것을',
#   '설탕',
#   '이고',
#   '설탕',
#   '진짜',
#   '많은',
#   '음식',
#   '보존',
#   '하기',
#   '위해서',
#   '사용',
#   '되고',
#   '있다'],
#  ['랍스터', '라는', '비싸고', '그게', '대표', '되었다'],
#  ['콜라는', '오븐', '구워도', '되고', '수프', '섞어', '먹어도', '된다'],
#  ['새로운', '연구', '섭취', '양을', '측정', '최초', '이다'],
#  ['그러나', '마지막', '단계', '로서', '이것', '대중', '공유', '되어야한다', '그들', '배우기', '위해'],
#  ['세계', '보건', '기구', '세계', '인구', '대략', '80', '약초', '기피한다고', '추정', '한다'],
#  ['다리', '넘어', '이주', '있었다고', '반증하는', '증거'],
#  ['인류학자들은',
#   '세번째',
#   '어금니인',
#   '사랑니',
#   '선조들의',
#   '얇고',
#   '부드러운',
#   '초기',
#   '음식',
#   '흙',
#   '뿌리',
#   '그리고',
#   '고기',
#   '같은',
#   '진화',
#   '문제점',
#   '이라고',
#   '믿는다',
#   '그런데',
#   '이것',
#   '씹는',
#   '힘을',
#   '줄어',
#   '들게',
#   '만들었다'],
#  ['가격', '잠시', '증가', '하겠지만', '다시', '곧', '떨어진다'],
#  ['반면에', '이성', '적인', '것은', '이해', '목표', '로해서', '현실', '필수적', '이다'],
#  ['온라인', '서점은', '고객', '반긴다'],
#  ['일부',
#   '할리우드',
#   '유명인사',
#   '들은',
#   '스피드킹',
#   '긴',
#   '기다림줄에',
#   '가입',
#   '했고',
#   '잡지에서는',
#   '줄이없는',
#   '욕망',
#   '이라고',
#   '했다'],
#  ['도로', '주자창이', '있는', '수백', '헥타르', '농경지', '많으면', '산업', '국가', '된다'],
#  ['여러',
#   '문제',
#   '발생',
#   '시키는',
#   '자동차',
#   '이동',
#   '의존',
#   '대한',
#   '증가',
#   '하는',
#   '증거',
#   '들이',
#   '있다'],
#  ['필', '굿'],
#  ['선생님', '과', '학생들', '오늘', '호박파이', '자르는', '것에', '대해', '이야기', '나눈다'],
#  ['냄새', '궁금해'],
#  ['가난한', '남자', '약간', '당황', '했다'],
#  ['누가', '완벽', '하다고', '외칠', '것만', '같았따'],
#  ['이곳이', '출구라고', '알려줌'],
#  ['과정', '에서', '인간', '자연', '가치', '위에', '놓을', '때만', '자연', '오직', '자원', '되낟'],
#  ['2000년에', '그의', '집에서', '죽음'],
#  ['바다', '뱀이', '다른', '뱀보다', '훨씬더', '독성이', '강하다'],
#  ['부정확', '진술', '과', '열린해석'],
#  ['가격', '오를수록', '수요', '상승', '한다'],
#  ['스스로', '지킬', '있음에도', '불구하고', '자주', '공격', '당할수록', '다칠', '가능성이', '많아진다'],
#  ['마지막',
#   '으로',
#   '적절',
#   '하지',
#   '못한',
#   '사전',
#   '보통',
#   '만드는데',
#   '10분',
#   '이면',
#   '충분',
#   '하다',
#   '그리고',
#   '이것',
#   '완성',
#   '될',
#   '즈음',
#   '에는',
#   '단어',
#   '뜻이',
#   '전혀',
#   '맞지',
#   '않는다'],
#  ['가격', '오르는게', '증가', '하기때문에', '수요', '낯설다'],
#  ['이런', '행동', '차와', '시계', '옷', '시장', '에서', '보여진다'],
#  ['쿠키', '개인', '프라이버시', '침해야', '대한', '우려', '성'],
#  ['광고', '에서는', '몇몇', '사람들이', '충분', '신뢰', '주는', '증거', '들을', '광고', '되어진다'],
#  ['형용사',
#   '80',
#   '긍정적',
#   '이고',
#   '의미',
#   '있고',
#   '의존하고',
#   '있다',
#   '형용사',
#   '적인',
#   '분류',
#   '필요',
#   '하다'],
#  ['컴퓨터', '화면을', '통한', '읽기는', '낮은', '읽기', '능력', '또한', '같이', '이끌었다'],
#  ['개는', '후각', '예민', '기계', '감지', '하지', '못하는', '냄새', '근원', '알아', '낼', '있다'],
#  ['사막화', '따듯한', '온도', '땅의', '습기를', '가져간다'],
#  ['그녀', '이야기', '듣던', '중', '소년', '호박', '파이', '대해', '질문', '했다'],
#  ['모든', '조건', '사람들', '궁전에', '몰려들기', '시작', '했다'],
#  ['옳은', '속도', '사용', '하여', '책을', '읽으면', '독서', '충돌', '막을', '있다'],
#  ['특허법의', '확대', '개인', '종자회사', '들이', '성장', '했다'],
#  ['그는', '이사해서', '보존', '된음식을', '제공', '했고', '작은', '공장', '세웠다'],
#  ['잠자리', '때', '피할', '수없는', '그라이스양은', '여전히', '동료', '이다'],
#  ['속담', '대부분', '거짓말'],
#  ['돈이', '있었으면', '좋겠다고', '생각', '하는', '것만으로는', '진짜', '사는게', '너무', '빡빡할수도있다'],
#  ['대한민국의', '법정', '공휴일', '월요일부터', '금요일까지', '지정', '되어야한다'],
#  ['쿠키', '혜택'],
#  ['천둥번개를', '동반', '폭풍우', '어디서', '나', '일반적', '으로', '볼', '있다'],
#  ['19세기', '이상주의', '모방', '하지만', '진짜', '다른', '건', '그가', '선택', '주제', '이다'],
#  ['고고학자',
#   '와',
#   '보조자는',
#   '발굴',
#   '18세기',
#   '물품',
#   '분류',
#   '하기전에',
#   '10년',
#   '보존',
#   '필요',
#   '하다'],
#  ['프린터', '토너는', '자주', '유지보수', '필요', '하다'],
#  ['많은',
#   '사람들',
#   '기꺼이',
#   '너를',
#   '도와',
#   '줄',
#   '것이므로',
#   '그들',
#   '도와주지',
#   '않을',
#   '것이라고',
#   '가정',
#   '하지',
#   '마라'],
#  ['많은',
#   '과학자들',
#   '더',
#   '많은',
#   '강수',
#   '예측',
#   '했지만',
#   '그들',
#   '예측',
#   '과는',
#   '다른',
#   '상황',
#   '발생',
#   '했다'],
#  ['자신', '거짓말쟁이', '아니라면', '금의', '단지', '달라고', '말하고', '있다'],
#  ['프로젝트', '일부', '비디오', '만들고', '있으며', '아이들', '촬영', '가능', '하는지', '물어보고', '있다'],
#  ['정직한', '학업', '의해', '얼어질', '있는', '것이', '그에게도', '다른', '학생들', '에게도', '이롭다'],
#  ['사람들', '인식', '날카롭지', '않음'],
#  ['최후통첩', '게임'],
#  ['어떤일', '일어', '날까'],
#  ['갈등', '부분적', '으로', '해결', '되거나', '새로운갈등이', '나타', '난다'],
#  ['너가', '한가할때', '문의하면', '바쁠때보다', '환영', '받는다'],
#  ['약간', '니즈', '알', '있지만', '한가지', '단점이', '있다'],
#  ['개무시'],
#  ['콜라는', '맛있고', '음식', '어울리고', '건강', '에도', '좋다'],
#  ['그들',
#   '정당한',
#   '직업',
#   '에서',
#   '돈을',
#   '벌고',
#   '최선',
#   '다해',
#   '노력',
#   '글을',
#   '쓰기위한',
#   '시간',
#   '얻는다'],
#  ['의학기술', '발전', '으로', '암환자들은', '많이', '살아', '난다'],
#  ['소리', '들림'],
#  ['송어', '낚시', '높은', '성취', '감을', '가졌다'],
#  ['결과', '수차례', '자걱을', '되풀이하고', '확고', '해짐'],
#  ['뿐만', '아니라', '그', '하나의', '사전', '알파벳', '순서', '완전', '엉망', '진창이다'],
#  ['리즈는',
#   '어두운',
#   '모습',
#   '밖으로',
#   '기는',
#   '것을',
#   '봤다',
#   '그리고',
#   '나무들',
#   '쪽으로',
#   '가까이',
#   '끄는',
#   '것을',
#   '봤다'],
#  ['도시',
#   '한가운데',
#   '있는',
#   '농장',
#   '에서',
#   '그의',
#   '생은',
#   '아주',
#   '잠깐',
#   '이었지만',
#   '그는',
#   '그가',
#   '썼던',
#   '삶을',
#   '살았다'],
#  ['공룡은', '65만년전에', '지구', '지배'],
#  ['베블런',
#   '말하는',
#   '좋은',
#   '것은',
#   '더',
#   '낮은',
#   '가격',
#   '정교한',
#   '거',
#   '보다',
#   '더',
#   '높은',
#   '질을',
#   '알수',
#   '없다'],
#  ['과한', '두', '개념', '사용', '도움이', '되지', '않는다'],
#  ['도전', '자는', '1명', '이나', '2명이', '쓰러질때까지', '계속', '되어야', '한다'],
#  ['멍청한', '사람', '실수', '하면', '나쁘게', '받아들여지나요'],
#  ['만야게',
#   '장애',
#   '부모',
#   '결과',
#   '거나',
#   '다른',
#   '부산물이라고',
#   '주장',
#   '하는',
#   '가족',
#   '간의',
#   '주자잉',
#   '있다'],
#  ['쌤들이',
#   '잘하는',
#   '것도',
#   '있지만',
#   '학생',
#   '서술형으로',
#   '평가',
#   '하는',
#   '거는',
#   '진짜',
#   '너무',
#   '화날',
#   '때가',
#   '있음'],
#  ['카페테리아',
#   '라는',
#   '용어',
#   '직원들',
#   '구내식당',
#   '내에서',
#   '선택',
#   '비슷',
#   '하기',
#   '때문',
#   '사용',
#   '된다'],
#  ['그는', '황금', '사과', '왕에게', '요청하고', '있다'],
#  ['개발',
#   '이전',
#   '사용',
#   '하지',
#   '않은',
#   '자원',
#   '어떻게',
#   '자원',
#   '제공',
#   '하게',
#   '될',
#   '것인가',
#   '주장',
#   '한다'],
#  ['아이', '랑', '친해지고', '싶으면', '그', '아이', '긍정적', '으로', '선택', '해야', '한다'],
#  ['침착', '하려', '노력'],
#  ['가족', '력', '없음'],
#  ['그러나', '일부', '연구원들은', '과장', '되었다고', '반박한다'],
#  ['인간', '쉽게', '숫자', '잘', '학습하고', '동물들', '수백', '번의', '반복', '필요로', '한다'],
#  ['이것',
#   '무섭고',
#   '가속',
#   '되고',
#   '세계',
#   '회가',
#   '오면',
#   '우리',
#   '불안정하고',
#   '잠재적',
#   '이고',
#   '힘이',
#   '있다'],
#  ['그에', '대해', '아무것도', '모르는데'],
#  ['시간', '대해', '층층이', '쌓여지는', '것은', '많은', '다른', '성분', '이다'],
#  ['마이애미',
#   '경찰서',
#   '실수',
#   '절대',
#   '용납하지',
#   '않고',
#   '강압적인',
#   '수사를',
#   '기반',
#   '으로',
#   '마이애미',
#   '사로',
#   '잡고',
#   '있다'],
#  ['랍스터', '비싸짐'],
#  ['바이러스', '만드는', '사람들', '그들', '모든', '시간', '여기에', '투자', '하지', '않는다'],
#  ['송골매', '제비갈매기에', '포함', '되는데', '둘다', '멸종위기', '종이다'],
#  ['밥은', '꼭꼭', '씹어', '먹고', '빈랑나무', '열매인', '판을', '먹자'],
#  ['멕시코', '범죄자', '많아서', '초록금이', '인기', '많다'],
#  ['극적', '이지', '않는', '것들', '평가', '절하한다'],
#  ['이게', '더', '달다고', '엄마', '에게', '말하고', '있다'],
#  ['왕은', '그에게', '자신', '빚지고', '있지', '않다고', '말함'],
#  ['옥수수', '잡종', '번식이후에', '종자', '역할', '분화', '속도', '빨라짐'],
#  ['대기업들은', '저가시장', '무시', '한다'],
#  ['그는', '흑인', '이고', '최초', '여성', '이고', '우주선', '되었다'],
#  ['그는', '그', '이름', '따라', '지어진것', '같은', '경제학자', '과시적', '소비'],
#  ['지리', '인간관계', '영향', '줌'],
#  ['콜라비', '날것으로', '먹을', '있다'],
#  ['그가', '나의', '신체', '대해', '알자마자', '문앞에', '경사로', '어떻게', '지을지', '계획', '했다'],
#  ['1900년대',
#   '초반',
#   '시에대한',
#   '관심',
#   '런던',
#   '에서',
#   '높아졌다',
#   '그리고',
#   '런던',
#   '시의',
#   '도시',
#   '되었다'],
#  ['서양', '사람들은', '동양', '문화', '와', '관점', '모을때', '기본적', '내용', '놓치다'],
#  ['화장품', '과', '웃은', '급격히', '증가'],
#  ['음식', '과', '유기농', '상품', '에도', '속도', '증가'],
#  ['때때로',
#   '너는',
#   '더',
#   '부유',
#   '해진다',
#   '혼란',
#   '스러움을',
#   '제거',
#   '하면서',
#   '사로',
#   '잡히지',
#   '않는다'],
#  ['전자',
#   '우리',
#   '생각',
#   '하는',
#   '것보다',
#   '더',
#   '드물게',
#   '일어',
#   '나고',
#   '후자',
#   '우리',
#   '생각',
#   '하는',
#   '것보다',
#   '더',
#   '높게',
#   '일어',
#   '난다'],
#  ['감정',
#   '나눌',
#   '누군가',
#   '있다면',
#   '너의',
#   '감정',
#   '나누어야한다',
#   '그러면',
#   '더',
#   '나은',
#   '삶을',
#   '가질',
#   '있다'],
#  ['면역체계',
#   '이를',
#   '기억하고',
#   '후에',
#   '같은',
#   '상황',
#   '발생',
#   '해도',
#   '사람',
#   '알',
#   '없게',
#   '빠르게',
#   '처리',
#   '한다'],
#  ['반면에', '많은', '사람들', '두번째', '소음', '선택', '했다'],
#  ['차는', '중국', '지역', '퍼진', '후에', '삶을', '변화', '하는', '역할', '했다'],
#  ['해양생물', '갑각류', '포함하고', '문을', '닫았다'],
#  ['그녀', '의학', '학위를', '받았다'],
#  ['땅에', '가까운', '공기', '데워지고', '가벼워진다'],
#  ['자격', '증있으면', '취업', '잘댐'],
#  ['블랙홀', '0이고', '작은데', '기본적', '물리법칙은', '부지깽이', '방출하고', '있다'],
#  ['일본', '가면', '일본어', '배울', '있다'],
#  ['19세기에는', '자동차', '나오고', '난', '후', '모든', '아이들', '모형', '자동차', '가저야만', '했다'],
#  ['예를', '들어', '쿠키', '사이트', '에서의', '유저의', '이름', '과', '주소를', '저장', '해놓는다'],
#  ['5억', '2천만분의', '5분의', '4가', '있는', '농경지', '있는', '산업', '발생', '국가', '있다'],
#  ['라임', '20달렁였는데', '이제는', '존나', '비싸다'],
#  ['시간', '팽창은', '실험실', '에서', '연구', '될', '것이다'],
#  ['그는', '기도', '하는', '중에', '믿을', '없는', '평화', '찾아왔다'],
#  ['자동차', '비율', '감소', '갷', '고', '대중', '교통은', '증가', '했고', '자전거', '많이', '탐'],
#  ['왕은', '그에게', '거짓말쟁이', '라고', '말했다'],
#  ['왕은', '자신', '함정', '빠진', '것을', '깨달았다'],
#  ['자기', '계발', '책은', '긍정적', '생각', '과', '행동들', '장려', '한다'],
#  ['그의', '공연', '가장', '긴', '원맨쇼로', '역사', '남음'],
#  ['코넬', '대학', '에서', '일하고', '다른', '대학', '에서', '또', '일함'],
#  ['이성', '물리적', '생존', '위해', '예측하고', '필수적', '이고', '개인', '과', '사회', '필요', '하다'],
#  ['물방울은', '무거워지고', '땅으로', '떨어진다'],
#  ['범죄', '통제', '좋은', '방법', '예방', '이다'],
#  ['오래', '된거는', '진짜', '넘나', '바꾸기', '어려움'],
#  ['엄격', '하게', '말하면', '무성', '생식', '속담', '이고', '정자와', '난자', '없이', '창조', '된다'],
#  ['천체',
#   '더',
#   '느리게',
#   '회전',
#   '할수록',
#   '적도',
#   '쪽이',
#   '천체',
#   '중심',
#   '으로',
#   '더',
#   '들어가게',
#   '된다',
#   '그리고',
#   '양극',
#   '부분',
#   '더욱',
#   '뾰족하게',
#   '변한다'],
#  ...]

# %% [markdown]
# # Translator

# %%
# from googletrans import Translator
# translator = Translator()

# sents = list(student['answer'].str.replace('[^0-9가-힣ㄱ-ㅎㅏ-ㅣ]',' '))
# ans = []
# for sent in sents:
#     try:
#         tar = translator.translate(sent, dest="en") 
#         ans.append(tar)
#         print(tar)
#     except:
#         ans.append('')
# ans

# %%
# ans = [i.text for i in ans]
# pd.DataFrame(ans).to_csv('./student_trans.csv')

# %% [markdown]
# # tf-idf part1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
target = list(teacher['answer'].str.replace('[^0-9가-힣]',' '))
target.extend(list(student['answer'].str.replace('[^0-9가-힣]',' ')))

answer1 = pd.DataFrame()
answer1['st_answer'] = student['answer']
answer1['te_answer'] = teacher['answer']
answer1['label'] = student['label']

# 토크나이저, 스탑워드 사용
for j in range(1,4):
    tfidf = TfidfVectorizer(tokenizer=tokenizer,stop_words=stop_words,ngram_range=(j,j)).fit(target)
    st_vector = tfidf.transform(student['answer'])
    te_vector = tfidf.transform(teacher['answer'])
    scores = [float(cosine_similarity(st_vector[i],te_vector[i])) for i in range(len(answer1))]
    answer1[f'{j}gram'] = scores

# %%
answer1
# Out:
#                                      st_answer  \
# 0              너는 농작물 밭에서 온도를 측정할 필요가 있다고 가정해라
# 1                               지식에는 다른 종류가 있다
# 2                                          왜일까
# 3        너는 완벽할 수 있지만  그것을 생각하는 방식을 변화할 필요가 있다
# 4     그는 유니크한 퍼포먼스 방법으로 알려져있는 바이올리니스트이자 작곡가였다
# ...                                        ...
# 1729                       또는 등장인물의 관점애서 난
# 1730                                     얘
# 1731        만약 이야기하기에 한가지 비밀이 있다면 난 그게 이거라 믿는다
# 1732                                       디에고
# 1733                      동물들은많은다양한이유들로유명해질수있다
#
#                                               te_answer  label     1gram  \
# 0                      당신이 농작물 밭에서 온도를 측정할 필요하다고 가정해보자       1  0.599107
# 1                                        다른 종류의 지식이 있다       1  0.849616
# 2                                                왜 그럴까       1  0.000000
# 3     여러분은 완벽할 수 있다  하지만 여러분은 그것 완벽함 에 대해 여러분이 생각하는 ...      1  0.495286
# 4                그는 그의 독특한 연주 방법으로 알려진 바이올리니스트이자 작곡가였다       1  0.538268
# ...                                                 ...    ...       ...
# 1729                         또는 그 등장인물의 관점에서  나는 누구인가        1  0.482320
# 1730                                         이 사람은 누구인가      1  0.000000
# 1731  만약 이야기하는 일에 한 가지 비밀이 있다면   그렇다면  나는 그것이 이것이라고 ...      1  0.442056
# 1732                                                         1  0.000000
# 1733                      동물들은 많은 여러 가지 이유들로 유명해질 수 있다       1  0.225405
#
#          2gram     3gram
# 0     0.361024  0.266093
# 1     0.235235  0.000000
# 2     0.000000  0.000000
# 3     0.201255  0.084286
# 4     0.298015  0.111124
# ...        ...       ...
# 1729  0.179716  0.000000
# 1730  0.000000  0.000000
# 1731  0.180508  0.000000
# 1732  0.000000  0.000000
# 1733  0.000000  0.000000
#
# [1734 rows x 6 columns]

# %% [markdown]
# # tf-idf part2

# %%
trans = pd.read_csv('./student_trans.csv')
answer2 = pd.DataFrame()
answer2['trans_answer'] = trans['0'].str.replace('[^0-9a-zA-Z]',' ')
answer2['question'] = student['sentence'].str.replace('[^0-9a-zA-Z]',' ')
answer2['label'] = student['label']


target = list(answer2['question'])
target.extend(list(answer2['trans_answer']))

for j in range(1,5):
    tfidf = TfidfVectorizer(ngram_range=(j,j)).fit(target)
    st_vector = tfidf.transform(answer2['trans_answer'])
    te_vector = tfidf.transform(answer2['question'])
    scores = [float(cosine_similarity(st_vector[i],te_vector[i])) for i in range(len(answer2))]
    answer2[f'trans_{j}gram'] = scores

# %%
answer2
# Out:
#                                            trans_answer  \
# 0     Suppose you need to measure the temperature in...
# 1                There are different kinds of knowledge
# 2                                             Why is it
# 3     You can be perfect  but you need to change the...
# 4     He was a violinist and composer known as a uni...
# ...                                                 ...
# 1729  Or is it because of the perspective of the cha...
# 1730                                           His one
# 1731  If I have a secret  I believe that if I have a...
# 1732                                              Diego
# 1733        Animals can become famous for many reasons
#
#                                                question  label  trans_1gram  \
# 0     Suppose you need to measure the temperature in...      1     0.995607
# 1               There are different kinds of knowledge       1     1.000000
# 2                                                  Why       1     0.812342
# 3     You can be perfect  but you need to change the...      1     1.000000
# 4     He was a violinist and composer known for his ...      1     0.938912
# ...                                                 ...    ...          ...
# 1729  Or  from the perspective of the character  Who...      1     0.691174
# 1730                                Who is this person       1     0.000000
# 1731  If there s a single secret to storytelling the...      1     0.554813
# 1732                                              Diego      1     1.000000
# 1733  Animals can become famous for many different r...      1     0.933322
#
#       trans_2gram  trans_3gram  trans_4gram
# 0        0.850657     0.668330     0.646124
# 1        1.000000     1.000000     1.000000
# 2        0.000000     0.000000     0.000000
# 3        1.000000     1.000000     1.000000
# 4        0.713160     0.552313     0.363697
# ...           ...          ...          ...
# 1729     0.474348     0.379573     0.288073
# 1730     0.000000     0.000000     0.000000
# 1731     0.000000     0.000000     0.000000
# 1732     0.000000     0.000000     0.000000
# 1733     0.754516     0.710747     0.649062
#
# [1734 rows x 7 columns]

# %% [markdown]
# # RandomForest Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

train_data = pd.DataFrame()
train_data['1gram'] = answer1['1gram']
train_data['2gram'] = answer1['2gram']
train_data['3gram'] = answer1['3gram']
# train_data['4gram'] = answer1['4gram']


train_data['trans_1gram'] = answer2['trans_1gram']
train_data['trans_2gram'] = answer2['trans_2gram']
train_data['trans_3gram'] = answer2['trans_3gram']
# train_data['trans_4gram'] = answer2['trans_4gram']

train_label = answer2['label']


X_train,X_test,y_train,y_test = train_test_split(
    train_data,train_label,test_size=0.15,random_state=10
)

from sklearn.ensemble import RandomForestClassifier

bootstrap = []
for i in range(100): # 랜덤추출
    rf = RandomForestClassifier(random_state=i)
    rf.fit(X_train,y_train)
    pred = rf.predict(X_test)
    acc = accuracy_score(pred,y_test)
    print(acc)
    bootstrap.append(acc)
# Out:
# 0.7662835249042146
# 0.7662835249042146
# 0.7662835249042146
# 0.7701149425287356
# 0.7662835249042146
# 0.7662835249042146
# 0.7739463601532567
# 0.7586206896551724
# 0.7701149425287356
# 0.7624521072796935
# 0.7624521072796935
# 0.7739463601532567
# 0.7547892720306514
# 0.7662835249042146
# 0.7816091954022989
# 0.7662835249042146
# 0.7509578544061303
# 0.7624521072796935
# 0.7509578544061303
# 0.7547892720306514
# 0.7624521072796935
# 0.7624521072796935
# 0.7662835249042146
# 0.7624521072796935
# 0.7739463601532567
# 0.7586206896551724
# 0.7662835249042146
# 0.7624521072796935
# 0.7547892720306514
# 0.7586206896551724
# 0.7586206896551724
# 0.7739463601532567
# 0.7586206896551724
# 0.7586206896551724
# 0.7509578544061303
# 0.7931034482758621
# 0.7662835249042146
# 0.7816091954022989
# 0.7662835249042146
# 0.7624521072796935
# 0.7662835249042146
# 0.7547892720306514
# 0.7662835249042146
# 0.7777777777777778
# 0.7586206896551724
# 0.7624521072796935
# 0.7701149425287356
# 0.7662835249042146
# 0.7777777777777778
# 0.7816091954022989
# 0.7624521072796935
# 0.7624521072796935
# 0.7662835249042146
# 0.7777777777777778
# 0.7739463601532567
# 0.7816091954022989
# 0.7854406130268199
# 0.7739463601532567
# 0.7854406130268199
# 0.7586206896551724
# 0.7624521072796935
# 0.7624521072796935
# 0.7624521072796935
# 0.7624521072796935
# 0.7471264367816092
# 0.7777777777777778
# 0.7701149425287356
# 0.7931034482758621
# 0.7777777777777778
# 0.7701149425287356
# 0.7854406130268199
# 0.7471264367816092
# 0.7432950191570882
# 0.7777777777777778
# 0.7777777777777778
# 0.7739463601532567
# 0.7547892720306514
# 0.7777777777777778
# 0.7509578544061303
# 0.7624521072796935
# 0.7777777777777778
# 0.7662835249042146
# 0.7586206896551724
# 0.7624521072796935
# 0.7586206896551724
# 0.7777777777777778
# 0.7701149425287356
# 0.7662835249042146
# 0.7701149425287356
# 0.7662835249042146
# 0.7701149425287356
# 0.7701149425287356
# 0.7624521072796935
# 0.7662835249042146
# 0.7739463601532567
# 0.7701149425287356
# 0.7777777777777778
# 0.7586206896551724
# 0.7662835249042146
# 0.7777777777777778

# %%
CI = pd.Series(bootstrap)
CI.describe()
# Out:
# count    100.000000
# mean       0.767050
# std        0.009742
# min        0.743295
# 25%        0.762452
# 50%        0.766284
# 75%        0.773946
# max        0.793103
# dtype: float64

# %%
import scipy.stats

def conf_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

# %%
conf_interval(CI,confidence=0.95)
# Out:
# (0.7670498084291186, 0.7651168565698998, 0.7689827602883375)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
bootstrap1 = []
parms = {'n_estimators':list(range(50,150,10)),
         'max_depth':list(range(10))} 
rf_clf = RandomForestClassifier(random_state=12,n_jobs=-1,verbose=True) # n_jobs ?
grid_cv = GridSearchCV(rf_clf,param_grid=parms,cv=6,n_jobs=-1,scoring='accuracy')# ,param_grid=parms
grid_cv.fit(X_train,y_train)

#     print(grid_cv.best_estimator_)
#     print(grid_cv.best_params_)
#     print(round(grid_cv.best_score_,4))
pred = grid_cv.predict(X_test)
acc = accuracy_score(pred,y_test)
print(acc)
# Out:
# 0.7471264367816092
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 140 out of 140 | elapsed:    0.0s finished
