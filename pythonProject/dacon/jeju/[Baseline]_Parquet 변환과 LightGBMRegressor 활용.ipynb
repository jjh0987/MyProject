# %% [markdown]
# ## Import

# %%
# !pip install lightgbm

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import gc

# %% [markdown]
# ## 데이터 불러오기

# %%
train = pd.read_csv('C:/Users/User/Desktop/data/jeju/train.csv')
test = pd.read_csv('C:/Users/User/Desktop/data/jeju/test.csv')

# %%
train
# Out:
#                     id  base_date  day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623            1         17            0
# 1        TRAIN_0000001   20220728            1         21            0
# 2        TRAIN_0000002   20211010            4          7            0
# 3        TRAIN_0000003   20220311            0         13            0
# 4        TRAIN_0000004   20211005            6          8            0
# ...                ...        ...          ...        ...          ...
# 4701212  TRAIN_4701212   20211104            1         16            0
# 4701213  TRAIN_4701213   20220331            1          2            0
# 4701214  TRAIN_4701214   20220613            3         22            0
# 4701215  TRAIN_4701215   20211020            2          2            0
# 4701216  TRAIN_4701216   20211019            6          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4701217 entries, 0 to 4701216
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   id                     object
#  1   base_date              int64
#  2   day_of_week            int32
#  3   base_hour              int64
#  4   road_in_use            int64
#  5   lane_count             int64
#  6   road_rating            int64
#  7   road_name              object
#  8   multi_linked           int64
#  9   connect_code           int64
#  10  maximum_speed_limit    float64
#  11  vehicle_restricted     float64
#  12  weight_restricted      float64
#  13  height_restricted      float64
#  14  road_type              int64
#  15  start_node_name        object
#  16  start_latitude         float64
#  17  start_longitude        float64
#  18  start_turn_restricted  int32
#  19  end_node_name          object
#  20  end_latitude           float64
# ...

# %% [markdown]
# ## 데이터 전처리

# %%
str_col = ['day_of_week','start_turn_restricted','end_turn_restricted']
for i in str_col:
    le = LabelEncoder()
    le=le.fit(train[i])
    train[i]=le.transform(train[i])
    
    for label in np.unique(test[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test[i]=le.transform(test[i])

# %%
y_train = train['target'] 

X_train = train.drop(['id','base_date', 'target','road_name', 'start_node_name', 'end_node_name','vehicle_restricted'], axis=1)

test = test.drop(['id','base_date', 'road_name', 'start_node_name', 'end_node_name','vehicle_restricted'], axis=1)

print(X_train.shape)
print(y_train.shape)
print(test.shape)
# Out:
# (4701217, 17)
# (4701217,)
# (291241, 17)

# %% [markdown]
# ## 모델 선언 및 학습

# %%
LR = lgb.LGBMRegressor(random_state=42).fit(X_train, y_train)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
quad = PolynomialFeatures(degree=1) # ,include_bias=False

X = df.loc[:len(df)-1001,features]
y = df.loc[1:len(df)-1000,'Close']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# ## 추론

# %%
pred = LR.predict(test)

# %% [markdown]
# ## Submission

# %%
sample_submission = pd.read_csv('C:/Users/User/Desktop/data/jeju/sample_submission.csv')

# %%
sample_submission['target'] = pred
sample_submission.to_csv("./submit.csv", index = False)

# %%
sample_submission
# Out:
#                  id     target
# 0       TEST_000000  27.298710
# 1       TEST_000001  43.949243
# 2       TEST_000002  60.552621
# 3       TEST_000003  36.499322
# 4       TEST_000004  37.510570
# ...             ...        ...
# 291236  TEST_291236  45.902276
# 291237  TEST_291237  52.604831
# 291238  TEST_291238  21.964371
# 291239  TEST_291239  25.402628
# 291240  TEST_291240  41.406265
#
# [291241 rows x 2 columns]
