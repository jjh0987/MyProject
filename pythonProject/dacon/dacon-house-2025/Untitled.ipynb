# %%
import pandas as pd
import seaborn as sns

# %%
train = pd.read_csv('./train.csv')
train['총주차대수'] = train['총주차대수'].fillna(0)
train['전용면적'] = train['전용면적'].fillna(0)
train
# Out:
#               ID 매물확인방식          보증금      월세   전용면적  해당층    총층   방향   방수  욕실수  \
# 0     TRAIN_0000   현장확인  402500000.0  470000   0.00  NaN  15.0   서향  1.0  1.0
# 1     TRAIN_0001   현장확인  170500000.0  200000   0.00  3.0   4.0  남동향  2.0  1.0
# 2     TRAIN_0002   전화확인  114000000.0  380000   0.00  2.0   3.0   동향  1.0  1.0
# 3     TRAIN_0003   현장확인  163500000.0   30000  36.30  3.0   9.0  남동향  2.0  1.0
# 4     TRAIN_0004   현장확인  346000000.0  530000   0.00  3.0   3.0   동향  2.0  1.0
# ...          ...    ...          ...     ...    ...  ...   ...  ...  ...  ...
# 2447  TRAIN_2447   서류확인  159000000.0  550000  48.95  3.0   3.0   남향  2.0  1.0
# 2448  TRAIN_2448   서류확인  158500000.0  750000   0.00  2.0   4.0   남향  1.0  1.0
# 2449  TRAIN_2449   전화확인  329000000.0  610000  17.50  8.0  20.0  남서향  1.0  1.0
# 2450  TRAIN_2450   현장확인   31000000.0  400000  22.87  8.0   9.0  남동향  2.0  1.0
# 2451  TRAIN_2451   전화확인  126000000.0  340000  29.89  4.0   6.0   북향  2.0  1.0
#
# ...

# %%
train[(train['주차가능여부'] == '가능') & (train['총주차대수'] == 0)]
# Out:
#               ID 매물확인방식          보증금      월세   전용면적  해당층    총층   방향   방수  욕실수  \
# 46    TRAIN_0046   현장확인   20500000.0  500000  17.50  5.0  11.0   북향  1.0  1.0
# 60    TRAIN_0060   현장확인   77500000.0   60000    NaN  2.0   5.0   동향  1.0  1.0
# 82    TRAIN_0082   현장확인   89000000.0  390000  29.92  4.0   7.0  북서향  2.0  1.0
# 138   TRAIN_0138   현장확인  363500000.0  470000  33.80  3.0   7.0   남향  2.0  1.0
# 139   TRAIN_0139   현장확인  107000000.0  460000    NaN  2.0   6.0   서향  1.0  1.0
# ...          ...    ...          ...     ...    ...  ...   ...  ...  ...  ...
# 2405  TRAIN_2405   현장확인  409000000.0  690000    NaN  3.0   6.0   남향  1.0  1.0
# 2416  TRAIN_2416   전화확인  363500000.0  750000  35.93  2.0   4.0   남향  2.0  1.0
# 2420  TRAIN_2420   현장확인  111500000.0  280000    NaN  3.0   5.0   남향  2.0  1.0
# 2430  TRAIN_2430   현장확인  101500000.0  280000  27.51  6.0   7.0   서향  2.0  1.0
# 2450  TRAIN_2450   현장확인   31000000.0  400000  22.87  8.0   9.0  남동향  2.0  1.0
#
# ...

# %%
train[(train['전용면적'] == 0)]
# Out:
#               ID 매물확인방식          보증금      월세  전용면적  해당층    총층   방향   방수  욕실수  \
# 0     TRAIN_0000   현장확인  402500000.0  470000   0.0  NaN  15.0   서향  1.0  1.0
# 1     TRAIN_0001   현장확인  170500000.0  200000   0.0  3.0   4.0  남동향  2.0  1.0
# 2     TRAIN_0002   전화확인  114000000.0  380000   0.0  2.0   3.0   동향  1.0  1.0
# 4     TRAIN_0004   현장확인  346000000.0  530000   0.0  3.0   3.0   동향  2.0  1.0
# 6     TRAIN_0006   현장확인  348500000.0  400000   0.0  2.0   3.0  북동향  1.0  1.0
# ...          ...    ...          ...     ...   ...  ...   ...  ...  ...  ...
# 2437  TRAIN_2437   현장확인  151500000.0  650000   0.0  2.0   3.0   동향  1.0  1.0
# 2440  TRAIN_2440   현장확인   29500000.0  420000   0.0  3.0   4.0  남동향  2.0  1.0
# 2443  TRAIN_2443   현장확인   16500000.0  370000   0.0  4.0   9.0   남향  1.0  1.0
# 2445  TRAIN_2445   현장확인  341000000.0  740000   0.0  2.0   5.0   동향  1.0  1.0
# 2448  TRAIN_2448   서류확인  158500000.0  750000   0.0  2.0   4.0   남향  1.0  1.0
#
# ...

# %%
train[(train['전용면적'] == 0) & (train['허위매물여부'] == 1)]
# Out:
#               ID 매물확인방식          보증금      월세  전용면적  해당층   총층   방향   방수  욕실수  \
# 4     TRAIN_0004   현장확인  346000000.0  530000   0.0  3.0  3.0   동향  2.0  1.0
# 31    TRAIN_0031   현장확인  132000000.0  540000   0.0  2.0  3.0   서향  1.0  1.0
# 47    TRAIN_0047   현장확인   76000000.0  700000   0.0  3.0  5.0   서향  1.0  1.0
# 93    TRAIN_0093   전화확인  403500000.0  540000   0.0  4.0  5.0   동향  2.0  1.0
# 106   TRAIN_0106   현장확인   12500000.0  470000   0.0  NaN  7.0   동향  2.0  1.0
# ...          ...    ...          ...     ...   ...  ...  ...  ...  ...  ...
# 2392  TRAIN_2392   현장확인  130000000.0  250000   0.0  6.0  6.0   남향  1.0  1.0
# 2403  TRAIN_2403   현장확인   70000000.0  410000   0.0  3.0  4.0   북향  2.0  1.0
# 2408  TRAIN_2408   현장확인   81500000.0  310000   0.0  4.0  6.0   북향  2.0  1.0
# 2411  TRAIN_2411   현장확인  341000000.0  550000   0.0  5.0  6.0  남서향  1.0  1.0
# 2415  TRAIN_2415   현장확인   26500000.0  570000   0.0  3.0  4.0  북동향  2.0  1.0
#
# ...

# %%
train[train['매물확인방식'] == '전화확인']
# Out:
#               ID 매물확인방식          보증금      월세   전용면적  해당층    총층   방향   방수  욕실수  \
# 2     TRAIN_0002   전화확인  114000000.0  380000    NaN  2.0   3.0   동향  1.0  1.0
# 5     TRAIN_0005   전화확인  153000000.0  530000  29.50  NaN   3.0   남향  2.0  1.0
# 12    TRAIN_0012   전화확인  348500000.0  180000  23.14  2.0   5.0   동향  1.0  1.0
# 14    TRAIN_0014   전화확인  409000000.0  110000    NaN  3.0  10.0   남향  1.0  1.0
# 20    TRAIN_0020   전화확인   12500000.0   50000  29.88  NaN  10.0  남서향  2.0  1.0
# ...          ...    ...          ...     ...    ...  ...   ...  ...  ...  ...
# 2426  TRAIN_2426   전화확인  134000000.0  140000  29.60  5.0   9.0  남서향  1.0  1.0
# 2429  TRAIN_2429   전화확인  173500000.0  640000  23.07  3.0   4.0   남향  1.0  1.0
# 2446  TRAIN_2446   전화확인  365500000.0  190000  17.50  NaN  14.0   남향  1.0  1.0
# 2449  TRAIN_2449   전화확인  329000000.0  610000  17.50  8.0  20.0  남서향  1.0  1.0
# 2451  TRAIN_2451   전화확인  126000000.0  340000  29.89  4.0   6.0   북향  2.0  1.0
#
# ...

# %%
sns.distplot(train['허위매물여부'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2660\3086589065.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['허위매물여부'])
# <Axes: xlabel='허위매물여부', ylabel='Density'>
# C:\Users\User\anaconda3\envs\project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54728 (\N{HANGUL SYLLABLE HEO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\project\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   func(*args, **kwargs)
# ...
