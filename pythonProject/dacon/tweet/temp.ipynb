# %%
import pandas as pd
path = '/Users/junho/Desktop/data/Bitcoin_tweets.csv'
df = pd.read_csv(path)
df.columns
df.sort_values(by='date')
# Out:
# /Users/junho/tensorflow_macos_venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,6,7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                  user_name  \
# 21523                                       Iconic Holding
# 21524                                       Iconic Holding
# 21522                                       Iconic Holding
# 21521                                       Iconic Holding
# 21520                                      Nick Doevendans
# ...                                                    ...
# 2568102    #newcoinlisting #newlisting #crypto #cryptonews
# 2571714                        Via https://t.co/p6iec02QvX
# 2571715  #btc    #4chan  #blockchain https://t.co/1nPIY...
# 2572401                        Via https://t.co/p6iec02QvX
# 2572402   #btc    #4chan  #altcoin https://t.co/QhOSmTOdwa
# ...

# %%
sub_df = df.drop(['user_created','user_location','user_followers','user_friends',
         'user_favourites','user_verified','source','is_retweet'],axis=1)

sub_df
# Out:
#                                         user_name  \
# 0                                   DeSota Wilson
# 1                                        CryptoND
# 2                                       Tdlmatias
# 3                            Crypto is the future
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# ...                                           ...
# 2573250                            Captain Crytpo
# 2573251                                     nadya
# 2573252                              Crypto Cobra
# 2573253                                 Cryptonia
# 2573254                                Derviş BEY
#
#                                           user_description  \
# 0        Biz Consultant, real estate, fintech, startups...
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...
# 2        IM Academy : The best #forex, #SelfEducation, ...
# 3        I will post a lot of buying signals for BTC tr...
# 4        Co-founder @RENJERJerky | Forbes 30Under30 | I...
# ...
