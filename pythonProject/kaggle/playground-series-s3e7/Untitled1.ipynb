# %%
import pandas as pd

# %%
train = pd.read_csv('./train.csv').drop('id',axis=1)
origin = pd.read_csv('./archive/train__dataset.csv')
test = pd.read_csv('./test.csv').drop('id',axis=1)
# origin_test = pd.read_csv('./archive/train__dataset.csv')

# %%
print(test.columns)
print(len(test))
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests'],
#       dtype='object')
# 28068

# %%
train = pd.concat([train,origin],axis=0).drop_duplicates().reset_index(drop=True)
train
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     0                  2
# 1                 2               0                     1                  2
# 2                 2               0                     0                  1
# 3                 1               0                     0                  2
# 4                 2               0                     1                  0
# ...             ...             ...                   ...                ...
# 54568             2               0                     1                  1
# 54569             2               0                     0                  5
# 54570             2               0                     0                  1
# 54571             2               0                     0                  3
# 54572             1               0                     1                  1
#
# ...

# %%
train[train['avg_price_per_room'] > 200]['booking_status'].value_counts()
# Out:
# 0    500
# 1    433
# Name: booking_status, dtype: int64
